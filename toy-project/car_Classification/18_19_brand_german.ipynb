# %% [markdown]
# ### just start by 2018

# %%
str_30_2018 = '''1	VW	GOLF	211,512	228,227	235,935	270,952
2	VW	TIGUAN	74,749	71,437	63,979	58,978
3	VW	POLO	70,488	61,378	72,017	69,867
4	VW	PASSAT	70,007	72,430	80,900	97,586
5	MERCEDES	C-CLASS	62,784	68,584	66,898	67,549
6	SKODA	OCTAVIA	58,444	59,147	58,683	57,907
7	AUDI	A4, S4, RS4	53,340	59,469	61,597	52,493
8	MINI	MINI	50,494	46,705	44,010	39,714
9	FORD	FOCUS	49,279	45,391	47,990	51,677
10	OPEL	CORSA	47,848	51,349	55,191	52,741
11	FORD	FIESTA	47,224	41,750	43,887	45,424
12	OPEL	ASTRA	45,932	56,327	65,173	56,079
13	AUDI	A3, S3, RS3	45,901	49,820	57,176	57,858
14	SKODA	FABIA	44,900	49,917	49,947	45,018
15	BMW	1 SERIES	44,143	45,699	46,632	46,340
16	MERCEDES	E-CLASS	43,113	47,845	37,945	30,860
17	SEAT	LEON	43,045	44,946	46,010	42,125
18	VW	TOURAN	42,623	52,182	52,560	37,098
19	BMW	5 SERIES	42,358	42,840	30,055	33,108
20	FORD	KUGA	42,276	37,962	34,676	28,529
21	MERCEDES	GLK, GLC	40,438	39,397	26,255	16,503
22	VW	TRANSPORTER	39,433	39,390	40,875	33,768
23	BMW	2 SERIES	38,189	41,144	50,680	42,916
24	AUDI	A6, S6, RS6	37,170	38,856	41,341	44,095
25	VW	UP	35,401	36,685	36,592	38,877
26	VW	T-ROC	35,299	NA	NA	NA
27	MERCEDES	A-CLASS	35,252	29,257	34,270	32,658
28	BMW	3 SERIES	34,514	38,343	43,986	44,637
29	FIAT	500	31,590	29,836	32,677	33,908
30	BMW	X1	31,521	35,016	28,400	16,406
'''

# %%
brand_30_2018=[line.strip().split('\t') for line in str_30_2018.strip().split('\n')]

# %%
brand_30_2018
# Out:
# [['1', 'VW', 'GOLF', '211,512', '228,227', '235,935', '270,952'],
#  ['2', 'VW', 'TIGUAN', '74,749', '71,437', '63,979', '58,978'],
#  ['3', 'VW', 'POLO', '70,488', '61,378', '72,017', '69,867'],
#  ['4', 'VW', 'PASSAT', '70,007', '72,430', '80,900', '97,586'],
#  ['5', 'MERCEDES', 'C-CLASS', '62,784', '68,584', '66,898', '67,549'],
#  ['6', 'SKODA', 'OCTAVIA', '58,444', '59,147', '58,683', '57,907'],
#  ['7', 'AUDI', 'A4, S4, RS4', '53,340', '59,469', '61,597', '52,493'],
#  ['8', 'MINI', 'MINI', '50,494', '46,705', '44,010', '39,714'],
#  ['9', 'FORD', 'FOCUS', '49,279', '45,391', '47,990', '51,677'],
#  ['10', 'OPEL', 'CORSA', '47,848', '51,349', '55,191', '52,741'],
#  ['11', 'FORD', 'FIESTA', '47,224', '41,750', '43,887', '45,424'],
#  ['12', 'OPEL', 'ASTRA', '45,932', '56,327', '65,173', '56,079'],
#  ['13', 'AUDI', 'A3, S3, RS3', '45,901', '49,820', '57,176', '57,858'],
#  ['14', 'SKODA', 'FABIA', '44,900', '49,917', '49,947', '45,018'],
# ...

# %%
str_30_2017='''1	VW GOLF	228,227	235,935	270,952
2	VW PASSAT	72,430	80,900	97,586
3	VW TIGUAN	71,437	63,979	58,978
4	MERCEDES C-KLASSE	68,584	66,898	67,549
5	VW POLO	61,378	72,017	69,867
6	AUDI A4, S4, RS4	59,469	61,597	52,493
7	SKODA OCTAVIA	59,147	58,683	57,907
8	OPEL ASTRA	56,327	65,173	56,079
9	VW TOURAN	52,182	52,560	37,098
10	OPEL CORSA	51,349	55,191	52,741
11	SKODA FABIA	49,917	49,947	45,018
12	AUDI A3, S3, RS3	49,820	57,176	57,858
13	MERCEDES E-KLASSE	47,845	37,945	30,860
14	MINI	46,705	44,010	39,714
15	BMW 1ER	45,699	46,632	46,340
16	FORD FOCUS	45,391	47,990	51,677
17	SEAT LEON	44,946	46,010	42,125
18	BMW 5ER	42,840	30,055	33,108
19	FORD FIESTA	41,750	43,887	45,424
20	BMW 2ER	41,144	50,680	42,916
21	MERCEDES GLK, GLC	39,397	26,255	16,503
22	VW TRANSPORTER	39,390	40,875	33,768
23	AUDI A6, S6, RS6	38,856	41,341	44,095
24	BMW 3ER	38,343	43,986	44,637
25	FORD KUGA	37,962	34,676	28,529
26	VW UP	36,685	36,592	38,877
27	OPEL MOKKA	35,631	32,052	31,037
28	BMW X1	35,016	28,400	16,406
29	VW CADDY	32,934	32,191	27,468
30	FIAT 500	29,836	32,677	33,908'''

# %%
br_17_name = [' '.join(line.strip().split('\t')[1:2]) for line in str_30_2017.strip().split('\n')]

# %%
br_18_name = [' '.join(line.strip().split('\t')[1:3]) for line in str_30_2018.strip().split('\n')]

# %%
# !pip install google_images_download
# Out:
# Processing /Users/dps/Library/Caches/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab/google_images_download-2.8.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# ...

# %%
br_17_name
# Out:
# ['VW GOLF',
#  'VW PASSAT',
#  'VW TIGUAN',
#  'MERCEDES C-KLASSE',
#  'VW POLO',
#  'AUDI A4, S4, RS4',
#  'SKODA OCTAVIA',
#  'OPEL ASTRA',
#  'VW TOURAN',
#  'OPEL CORSA',
#  'SKODA FABIA',
#  'AUDI A3, S3, RS3',
#  'MERCEDES E-KLASSE',
#  'MINI',
#  'BMW 1ER',
#  'FORD FOCUS',
#  'SEAT LEON',
#  'BMW 5ER',
#  'FORD FIESTA',
#  'BMW 2ER',
#  'MERCEDES GLK, GLC',
#  'VW TRANSPORTER',
#  'AUDI A6, S6, RS6',
#  'BMW 3ER',
#  'FORD KUGA',
#  'VW UP',
#  'OPEL MOKKA',
#  'BMW X1',
#  'VW CADDY',
#  'FIAT 500']

# %%
br_18_name
# Out:
# ['VW GOLF',
#  'VW TIGUAN',
#  'VW POLO',
#  'VW PASSAT',
#  'MERCEDES C-CLASS',
#  'SKODA OCTAVIA',
#  'AUDI A4, S4, RS4',
#  'MINI MINI',
#  'FORD FOCUS',
#  'OPEL CORSA',
#  'FORD FIESTA',
#  'OPEL ASTRA',
#  'AUDI A3, S3, RS3',
#  'SKODA FABIA',
#  'BMW 1 SERIES',
#  'MERCEDES E-CLASS',
#  'SEAT LEON',
#  'VW TOURAN',
#  'BMW 5 SERIES',
#  'FORD KUGA',
#  'MERCEDES GLK, GLC',
#  'VW TRANSPORTER',
#  'BMW 2 SERIES',
#  'AUDI A6, S6, RS6',
#  'VW UP',
#  'VW T-ROC',
#  'MERCEDES A-CLASS',
#  'BMW 3 SERIES',
#  'FIAT 500',
#  'BMW X1']

# %% [markdown]
# - - -

# %% [markdown]
# [2018-CAR-SALE-BRAND](https://www.best-selling-cars.com/germany/2018-full-year-germany-best-selling-car-models/)

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()

# %%
# test if arguments can be variables

# %%
def download_img(given_car_lst):
    for car in given_car_lst:
        arguments = {"keywords":car, "print_urls" : True,  "prefix_keywords" : "german",
                    "type":"photo"}
        paths = response.download(arguments)
        print(paths)

# %%
# download_img(br_18_name)

# %%
for seven in br_17_name:
    if seven in br_18_name:
        print(f'{seven}')
        br_17_name.remove(seven)
# Out:
# VW GOLF
# VW TIGUAN
# VW POLO
# SKODA OCTAVIA
# VW TOURAN
# SKODA FABIA
# FORD FOCUS
# FORD FIESTA
# MERCEDES GLK, GLC
# AUDI A6, S6, RS6
# FORD KUGA
# BMW X1
# FIAT 500

# %%
download_img(br_17_name)
# Out:
# Item no.: 1 --> Item name = german VW PASSAT
# Evaluating...
# Starting Download...
# Image URL: https://i.ytimg.com/vi/RdhSnQocp1s/hqdefault.jpg
# Completed Image ====> 1.hqdefault.jpg
# Image URL: https://www.carscoops.com/wp-content/uploads/2015/05/VW-Passat-0.jpg
# Completed Image ====> 2.VW-Passat-0.jpg
# Image URL: https://s1.cdn.autoevolution.com/images/news/2015-volkswagen-passat-gets-new-petrol-engines-in-germany-18-tsi-and-20-tsi-91752_1.jpg
# IOError on an image...trying next one... Error: The read operation timed out
# Image URL: https://www.carscoops.com/wp-content/uploads/2014/11/VW-Passat-0.jpg
# Completed Image ====> 3.VW-Passat-0.jpg
# Image URL: https://www.motorward.com/wp-content/images/2014/10/Passat-R400.jpg
# Completed Image ====> 4.Passat-R400.jpg
# Image URL: https://i.pinimg.com/originals/e8/6c/ee/e86cee930049b7644bed921a6c6804ac.jpg
# Completed Image ====> 5.e86cee930049b7644bed921a6c6804ac.jpg
# ...
