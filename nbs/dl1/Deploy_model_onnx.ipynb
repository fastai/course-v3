# %% [markdown]
# This notebook is for converting pytorch using ONNX

# %% [markdown]
# Resources: [ONNX](https://github.com/onnx/tutorials) <br/>
# [Torch-onnx](https://pytorch.org/docs/master/onnx.html) <br/>
# [Lesson02](https://github.com/SpellOnYou/dlff-note/blob/master/nbs/dl1/lesson2-download.ipynb) <br/>

# %%
# !pip install tensorflow-gpu
# !pip install torch torchvision
# !pip install onnx
# !git clone https://github.com/onnx/onnx-tensorflow.git

# %%
import os
os.chdir('/content/onnx-tensorflow/')

# %%
# !python setup.py install --user

# %%
import tensorflow as tf
import torch
import onnx
from onnx_tf.backend import prepare
# Out:
# /content/onnx-tensorflow/onnx_tf/common/__init__.py:89: UserWarning: onnx_tf.common.get_outputs_names is deprecated. It will be removed in future release. Use TensorflowGraph.get_outputs_names instead.
#   warnings.warn(message)

# %% [markdown]
# -----train the model

# %%
from fastai.vision import *

# %%
folders=['VW GOLF', 'VW TIGUAN', 'VW POLO','VW PASSAT','MERCEDES C-CLASS','SKODA OCTAVIA','AUDI A4','AUDI S4','AUDI RS4','MINI MINI',
        'FORD FOCUS','OPEL CORSA','FORD FIESTA','OPEL ASTRA']

for fld in folders:
    path = Path('/content/data/car')
    dest = path/fld
    dest.mkdir(parents=True, exist_ok=True)
    file = fld+'.csv'
    download_images(path/file, dest, max_pics=200)

# %%
classes = folders

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=2700)
# Out:
# VW GOLF
# VW TIGUAN
# VW POLO
# VW PASSAT
# MERCEDES C-CLASS
# SKODA OCTAVIA
# AUDI A4
# AUDI S4
# AUDI RS4
# MINI MINI
# FORD FOCUS
# OPEL CORSA
# FORD FIESTA
# OPEL ASTRA

# %% [markdown]
# What does meaning of `vision.data size params?`

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=330, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['AUDI A4',
#  'AUDI RS4',
#  'AUDI S4',
#  'FORD FIESTA',
#  'FORD FOCUS',
#  'MERCEDES C-CLASS',
#  'MINI MINI',
#  'OPEL ASTRA',
#  'OPEL CORSA',
#  'SKODA OCTAVIA',
#  'VW GOLF',
#  'VW PASSAT',
#  'VW POLO',
#  'VW TIGUAN']

# %%
data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (14, 1728, 432)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, wd=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(IntProgress(value=0, max=87306240), HTML(value='')))

# %% [markdown]
# ## Learn for frozen layers

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [3/4 00:44<00:14]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.116597</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.045167</td>
#       <td>#na#</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.995257</td>
#       <td>#na#</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='27', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       37.04% [10/27 00:06<00:11 12.5186]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 5e-03

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.525578</td>
#       <td>1.992119</td>
#       <td>0.627315</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.619701</td>
#       <td>2.126146</td>
#       <td>0.662037</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.576510</td>
#       <td>2.039678</td>
#       <td>0.627315</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442980</td>
#       <td>1.979206</td>
#       <td>0.599537</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.332447</td>
#       <td>1.965237</td>
#       <td>0.592593</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [3/4 00:45<00:15]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.197883</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.285627</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.765889</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='27', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.81% [4/27 00:02<00:16 4.4266]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(7, max_lr=slice(5e-05,lr/10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.189466</td>
#       <td>1.951638</td>
#       <td>0.576389</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.139849</td>
#       <td>2.031852</td>
#       <td>0.611111</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.033634</td>
#       <td>2.049625</td>
#       <td>0.615741</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.896094</td>
#       <td>2.003143</td>
#       <td>0.567130</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.715108</td>
#       <td>1.970834</td>
#       <td>0.569444</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.558780</td>
#       <td>1.901478</td>
#       <td>0.557870</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.471356</td>
#       <td>1.894974</td>
#       <td>0.546296</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=330, num_workers=4).normalize(imagenet_stats)

# %%
tfms = get_transforms(do_flip=True)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=230, train='.', num_workers=16, bs=32, valid_pct=0.2).normalize(imagenet_stats)

# %%
learn.freeze_to(2)
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 00:30<00:30]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.355646</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.331709</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='27', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       85.19% [23/27 00:13<00:02 1.2910]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8, max_lr=slice(5e-05, 2e-03))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.311569</td>
#       <td>1.914680</td>
#       <td>0.550926</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.305155</td>
#       <td>1.998549</td>
#       <td>0.518519</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.307317</td>
#       <td>2.123023</td>
#       <td>0.520833</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.308709</td>
#       <td>2.160908</td>
#       <td>0.523148</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.285030</td>
#       <td>2.185613</td>
#       <td>0.532407</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.250936</td>
#       <td>2.206881</td>
#       <td>0.520833</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.232816</td>
#       <td>2.229700</td>
#       <td>0.518519</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.232820</td>
#       <td>2.238598</td>
#       <td>0.518519</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-3')

# %% [markdown]
# About image size
# - [Document](https://docs.fast.ai/vision.data.html)
# - [forum](https://forums.fast.ai/t/best-way-to-resize-pictures-for-model-training/28307/22)

# %%
learn.load('stage-3')

# %%
from fastai.callbacks.hooks import *
from fastai.utils.mem import *
free = gpu_mem_get_free_no_cache()
free
# Out:
# 14617

# %%
src=ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, bs=16,
                               ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
#attribute error
# data = (src.transform(get_transforms()
#         # , size=size
#         ,)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %%
learn = cnn_learner(src, models.resnet34, metrics=error_rate)

# %%
learn.load('stage-3')

# %%
lr_find(learn)
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='78' class='' max='107', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       72.90% [78/107 00:12<00:04 2.4842]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.58E-06
# Min loss divided by 10: 1.91E-05

# %%
lr =1.58E-06
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.915594</td>
#       <td>0.390584</td>
#       <td>0.100467</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.876138</td>
#       <td>0.402183</td>
#       <td>0.102804</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.940522</td>
#       <td>0.403678</td>
#       <td>0.102804</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.907052</td>
#       <td>0.400356</td>
#       <td>0.102804</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.873639</td>
#       <td>0.397092</td>
#       <td>0.100467</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.863783</td>
#       <td>0.397848</td>
#       <td>0.098131</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.874066</td>
#       <td>0.391291</td>
#       <td>0.102804</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.882566</td>
#       <td>0.392054</td>
#       <td>0.095794</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.928212</td>
#       <td>0.403511</td>
#       <td>0.107477</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.830263</td>
#       <td>0.397166</td>
#       <td>0.100467</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-big', return_path=True)
# Out:
# PosixPath('data/cars/models/stage-1-big.pth')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='78' class='' max='107', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       72.90% [78/107 00:13<00:04 3.1826]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 5.25E-06

# %%
lrs = slice(6.31E-07,lr/10)
learn.fit_one_cycle(10, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.895550</td>
#       <td>0.393539</td>
#       <td>0.100467</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.877043</td>
#       <td>0.411422</td>
#       <td>0.105140</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.933294</td>
#       <td>0.406603</td>
#       <td>0.102804</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.920779</td>
#       <td>0.392009</td>
#       <td>0.107477</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.844603</td>
#       <td>0.398215</td>
#       <td>0.098131</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.925449</td>
#       <td>0.400156</td>
#       <td>0.100467</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.906099</td>
#       <td>0.401248</td>
#       <td>0.102804</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.839381</td>
#       <td>0.388991</td>
#       <td>0.100467</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.888014</td>
#       <td>0.398889</td>
#       <td>0.102804</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.894234</td>
#       <td>0.394684</td>
#       <td>0.102804</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
# show for site

# %%
src.show_batch(rows=5, figsize=(7,8))

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %% [markdown]
# -----------new era

# %%
learn.save('stage-4')

# %%
data2=ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, bs=16,
                               ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(src, models.resnet34, metrics=error_rate)
learn.load('stage-4')

# %%
learn.unfreeze()
lr_find(learn)
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='75' class='' max='107', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.09% [75/107 00:13<00:05 2.8344]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 4.79E-06
# Min loss divided by 10: 1.10E-07

# %%
lr =4.79E-06
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.871798</td>
#       <td>0.392361</td>
#       <td>0.105140</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.879623</td>
#       <td>0.403271</td>
#       <td>0.095794</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.922442</td>
#       <td>0.390996</td>
#       <td>0.093458</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.900683</td>
#       <td>0.396264</td>
#       <td>0.100467</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.899885</td>
#       <td>0.389998</td>
#       <td>0.107477</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.887227</td>
#       <td>0.395308</td>
#       <td>0.098131</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.816731</td>
#       <td>0.386561</td>
#       <td>0.102804</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.835803</td>
#       <td>0.397373</td>
#       <td>0.098131</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.899065</td>
#       <td>0.388938</td>
#       <td>0.102804</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.861731</td>
#       <td>0.399464</td>
#       <td>0.107477</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(title='german car confusion')

# %%
learn.export()
