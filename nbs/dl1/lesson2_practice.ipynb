# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# => So I will make a classifier which distinguish **Munich**, **Berlin**, **Hamburg**<br />
# before that, there needs some setup

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URL and download images

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# In Google Chrome press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>j</kbd> on Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>j</kbd> on macOS, and a small window the javascript 'Console' will appear. In Firefox press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>k</kbd> on Windows/Linux or <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>k</kbd> on macOS. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise the window.open() command doesn't work. Then you can run the following commands:
#
# ```javascript
# urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
folder = 'Munich'
file = 'urls_munich.csv'

# %%
folder = 'Berlin'
file = 'urls_berlin.csv'

# %%
folder = 'Dresden'
file = 'urls_dresden.csv'

# %% [markdown]
# You will need to run this cell once per each category.

# %%
path = Path('../../materials/dataset/url')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('../../materials/dataset/url/Dresden'),
#  PosixPath('../../materials/dataset/url/Munich'),
#  PosixPath('../../materials/dataset/url/Dresen'),
#  PosixPath('../../materials/dataset/url/urls_berlin.csv'),
#  PosixPath('../../materials/dataset/url/urls_munich.csv'),
#  PosixPath('../../materials/dataset/url/Berlin'),
#  PosixPath('../../materials/dataset/url/urls_dresden.csv')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](https://github.com/fastai/course-v3/blob/master/nbs/dl1/images/download_images/upload.png?raw=1)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['Berlin','Munich','Dresden']

# %%
download_images(path/file, dest, max_pics=200)

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:

# %% [markdown]
# ## 1.2 Using google_images_download

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()   #class instantiation
out_dir = os.path.abspath('../../materials/dataset/pkg/')
os.mkdir(out_dir)
arguments = {"keywords":"Munich,Berlin,Dresden",
             "print_urls":True,
#              "suffix_keywords":"Germany",
             "output_directory":out_dir,
             "type":"photo",
            }
paths = response.download(arguments)   #passing the arguments to the function
print(paths)
# Out:
# Item no.: 1 --> Item name = Munich
# Evaluating...
# Starting Download...
# Image URL: https://cdn.muenchen-p.de/.imaging/stk/responsive/galleryLarge/dms/shutterstock/neues-rathaus-marienplatz/document/neues-rathaus-marienplatz.jpg
# Completed Image ====> 1.neues-rathaus-marienplatz.jpg
# Image URL: https://cdn.muenchen-p.de/image/fetch/c_scale,w_1180/c_crop,g_center,h_442,w_1180/https://www.muenchen.de/media/shutterstock-2017/sehenswuerdigkeiten-2/rathaus-sonne-hp.jpg
# Completed Image ====> 2.rathaus-sonne-hp.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Stadtbild_M%C3%BCnchen.jpg/1200px-Stadtbild_M%C3%BCnchen.jpg
# Completed Image ====> 3.1200px-Stadtbild_M%C3%BCnchen.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-1378911-146.jpg
# Completed Image ====> 4.tour_img-1378911-146.jpg
# Image URL: https://static01.nyt.com/images/2019/09/24/travel/24PTG-Germany3-promo/24PTG-Germany3-promo-superJumbo-v2.jpg
# Completed Image ====> 5.24PTG-Germany3-promo-superJumbo-v2.jpg
# Image URL: https://static.independent.co.uk/s3fs-public/thumbnails/image/2016/03/23/13/munich-alamy.jpg?w968h681
# Completed Image ====> 6.munich-alamy.jpg
# Image URL: https://i.ytimg.com/vi/87Rztt8FeOU/maxresdefault.jpg
# Completed Image ====> 7.maxresdefault.jpg
# Image URL: https://cdn.muenchen-p.de/.imaging/stk/responsive/galleryLarge/dms/sw/mde/frauenkirche-4000/document/frauenkirche-4000.jpg
# Completed Image ====> 8.frauenkirche-4000.jpg
# Image URL: https://static01.nyt.com/images/2019/09/24/travel/24PTG-Germany3/merlin_160243626_f8f7f6c4-c329-4dff-af05-be978da4ac42-articleLarge.jpg?quality=75&auto=webp&disable=upscale
# Completed Image ====> 9.merlin_160243626_f8f7f6c4-c329-4dff-af05-be978da4ac42-articleLarge.jpg
# Image URL: https://handluggageonly.co.uk/wp-content/uploads/2016/10/Hand-Luggage-Only-2-1.jpg
# Completed Image ====> 10.Hand-Luggage-Only-2-1.jpg
# Image URL: https://www.deutschland.de/sites/default/files/styles/crop_story_content/public/media/image/munich-germany-bavaria-tourism-travel-holidays-alps.jpg?h=dd2f6e33&itok=25gyjaho
# Completed Image ====> 11.munich-germany-bavaria-tourism-travel-holidays-alps.jpg
# Image URL: https://media.timeout.com/images/105154039/630/472/image.jpg
# Completed Image ====> 12.image.jpg
# Image URL: https://cdn.tourcms.com/a/11676/19/1/default.jpg
# Completed Image ====> 13.default.jpg
# Image URL: https://static.neweuropetours.eu/wp-content/uploads/2018/09/thio-mun-ft-4-1600x900.jpg
# Completed Image ====> 14.thio-mun-ft-4-1600x900.jpg
# Image URL: https://static.accessmba.com/application/public/cache/event-munich-620x370.jpg
# Completed Image ====> 15.event-munich-620x370.jpg
# Image URL: https://static.amazon.jobs/locations/12/thumbnails/Munich_-_Thumbnail.jpg?1453901886
# Completed Image ====> 16.Munich_-_Thumbnail.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-1378998-146.jpg
# Completed Image ====> 17.tour_img-1378998-146.jpg
# Image URL: https://www.ef.com/sitecore/__~/media/efcom/2018/ils/destinations/Germany/Munich/Munich-Stage-Destop.jpg
# Completed Image ====> 18.Munich-Stage-Destop.jpg
# Image URL: https://cdn.britannica.com/05/152205-050-D3A09B6C/Munich-Germany.jpg
# Completed Image ====> 19.Munich-Germany.jpg
# Image URL: https://cdn.muenchen-p.de/image/fetch/c_scale,w_1180/c_crop,g_center,h_442,w_1180/https://www.muenchen.de/media/va-2016/muenchner-christkindlmarkt/christkindlmarkt-marienplat-logo-hp.jpg
# Completed Image ====> 20.christkindlmarkt-marienplat-logo-hp.jpg
# Image URL: https://www.tripsavvy.com/thmb/z4L-f7EX2vtMQhxPIL8E8bX98wo=/960x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-962642536-33584e0b843c4c2ba25e7e7922c97745.jpg
# Completed Image ====> 21.GettyImages-962642536-33584e0b843c4c2ba25e7e7922c97745.jpg
# Image URL: https://www.kellyprincewrites.com/wp-content/uploads/2019/03/Munich-KellyPrinceWright-2-1.jpg
# Completed Image ====> 22.Munich-KellyPrinceWright-2-1.jpg
# Image URL: https://cdn.thecrazytourist.com/wp-content/uploads/2017/09/ccimage-shutterstock_566911099.jpg
# Completed Image ====> 23.ccimage-shutterstock_566911099.jpg
# Image URL: https://icdn2.themanual.com/image/themanual/munichv2.jpg
# Completed Image ====> 24.munichv2.jpg
# Image URL: https://www.thelocal.de/userdata/images/article/8c29596c9f6db671bc25a5a5abc5d7cdec93f79ec9a53c81c4516490dcdf1185.jpg
# Completed Image ====> 25.8c29596c9f6db671bc25a5a5abc5d7cdec93f79ec9a53c81c4516490dcdf1185.jpg
# Image URL: https://cdn.britannica.com/06/152206-050-72BD5CAC/twin-towers-Church-of-Our-Lady-Munich.jpg
# Completed Image ====> 26.twin-towers-Church-of-Our-Lady-Munich.jpg
# Image URL: https://www.fattiretours.com/uploads/6906/HERO-M-fat-tire-tours-munich-homepage@2x.png
# Completed Image ====> 27.HERO-M-fat-tire-tours-munich-homepage@2x.png
# Image URL: https://s.abcnews.com/images/Lifestyle/munich-gty-jpo-170915_31x13_992.jpg
# Completed Image ====> 28.munich-gty-jpo-170915_31x13_992.jpg
# Image URL: https://zdnet4.cbsistatic.com/hub/i/r/2017/02/10/9befc3d2-7931-48df-8114-008d23f1941d/resize/770xauto/02ca33958e5288c81a85d3dac546f621/munich2.jpg
# Completed Image ====> 29.munich2.jpg
# Image URL: https://www.citybaseapartments.com/blog/wp-content/uploads/2019/11/Munich-centre.jpg
# Completed Image ====> 30.Munich-centre.jpg
# Image URL: https://cache.marriott.com/marriottassets/destinations/hero/munich-destination.jpg?interpolation=progressive-bilinear
# Completed Image ====> 31.munich-destination.jpg
# Image URL: https://cdn.muenchen-p.de/fl_progressive,q_65/.imaging/stk/responsive/teaser300/dms/shutterstock-2016/sehenswuerdigkeiten/friedensengel-aussicht-hp/document/friedensengel-aussicht-hp.jpg
# Completed Image ====> 32.friedensengel-aussicht-hp.jpg
# Image URL: https://arzotravels.com/wp-content/uploads/2019/07/town-hall-3620496_1280.jpg
# Completed Image ====> 33.town-hall-3620496_1280.jpg
# Image URL: https://www.younglife.org/Jobs/Area%20Director%20at%20Fort%20Belvoir/munich.jpg
# Completed Image ====> 34.munich.jpg
# Image URL: https://media-cdn.tripadvisor.com/media/photo-s/18/3c/74/8d/antiquarium.jpg
# Completed Image ====> 35.antiquarium.jpg
# Image URL: https://cdn.tourcms.com/a/11676/13/1/large.jpg
# Completed Image ====> 36.large.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-1025172-146.jpg
# Completed Image ====> 37.tour_img-1025172-146.jpg
# Image URL: https://media.timeout.com/images/105482757/630/472/image.jpg
# Completed Image ====> 38.image.jpg
# Image URL: https://s19623.pcdn.co/wp-content/uploads/2018/07/weekend-in-munich.jpg
# Completed Image ====> 39.weekend-in-munich.jpg
# Image URL: https://images.forwardcdn.com/image/300x225/center/images/cropped/munich-skyline-1565192839.jpg
# Completed Image ====> 40.munich-skyline-1565192839.jpg
# Image URL: https://www.telegraph.co.uk/content/dam/Travel/2019/September/munich-GettyImages-1145233171.jpg?imwidth=450
# Completed Image ====> 41.munich-GettyImages-1145233171.jpg
# Image URL: https://cdn.britannica.com/00/20100-050-30767C46/Patrons-Oktoberfest-beer-garden-Munich-Germany.jpg
# Completed Image ====> 42.Patrons-Oktoberfest-beer-garden-Munich-Germany.jpg
# Image URL: https://cdn2.veltra.com/ptr/20180511125344_96471845_10339_0.jpg?imwidth=480&impolicy=custom
# Completed Image ====> 43.20180511125344_96471845_10339_0.jpg
# Image URL: https://cdn.muenchen-p.de/fl_progressive,q_65/.imaging/stk/responsive/teaser300/dms/fs/jobs/document/jobs.jpg
# Completed Image ====> 44.jobs.jpg
# Image URL: https://www.european-traveler.com/wp-content/uploads/2015/12/Innsbruck.jpg
# Completed Image ====> 45.Innsbruck.jpg
# Image URL: https://www.dwf.law/-/media/DWF/Images/Locations-Assets/Munich/Munich---City-hall-at-the-Marienplatz.ashx?h=577&la=en&w=850
# Invalid or missing image format. Skipping...
# Image URL: https://media.tacdn.com/media/attractions-splice-spp-674x446/07/72/0f/81.jpg
# Completed Image ====> 46.81.jpg
# Image URL: https://www.bavaria.by/wp-content/uploads//2018/01/keyvisual-muenchner-oktoberfest-1024x369.jpg
# Completed Image ====> 47.keyvisual-muenchner-oktoberfest-1024x369.jpg
# Image URL: https://www.h-hotels.com/_Resources/Persistent/8c4815efac77042dc3230bb0cb317de066095dd5/muenchen-viktualienmarkt-02-600x355.jpg
# Completed Image ====> 48.muenchen-viktualienmarkt-02-600x355.jpg
# Image URL: https://cdn.thecrazytourist.com/wp-content/uploads/2017/09/ccimage-shutterstock_388744825.jpg
# Completed Image ====> 49.ccimage-shutterstock_388744825.jpg
# Image URL: https://www.telegraph.co.uk/content/dam/Travel/2019/April/munich-iStock-993538776.jpg?imwidth=450
# Completed Image ====> 50.munich-iStock-993538776.jpg
# Image URL: https://www.tosomeplacenew.com/wp-content/uploads/2018/12/Munich-Itinerary-Picture.jpg
# Completed Image ====> 51.Munich-Itinerary-Picture.jpg
# Image URL: https://themomentkeepers.com/wp-content/uploads/2018/07/Main-Munich.jpg
# Completed Image ====> 52.Main-Munich.jpg
# Image URL: https://img1.10bestmedia.com/Images/Photos/249855/p-4199761324-137d685ff5-b_54_990x660_201404251111.jpg
# Completed Image ====> 53.p-4199761324-137d685ff5-b_54_990x660_201404251111.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-1378962-146.jpg
# Completed Image ====> 54.tour_img-1378962-146.jpg
# Image URL: https://www.traveller.ee/blog/wp-content/uploads/2018/10/street-view-with-historic-buildings-in-nurnberg-germany-while-on-a-road-trip-from-prague-to-munich.jpg
# Completed Image ====> 55.street-view-with-historic-buildings-in-nurnberg-germany-while-on-a-road-trip-from-prague-to-munich.jpg
# Image URL: https://cdn2.veltra.com/ptr/20180601103107_486599874_10339_0.jpg?imwidth=480&impolicy=custom
# Completed Image ====> 56.20180601103107_486599874_10339_0.jpg
# Image URL: https://www.mikesbiketours.com/munich/images/Tour%20Photos%20570X%20380/Munich-&-Beyond.jpg
# Completed Image ====> 57.Munich-&-Beyond.jpg
# Image URL: https://www.tripsavvy.com/thmb/4mZycc29ZmuZYaUi5KllPBAb-qc=/5021x3347/filters:no_upscale():max_bytes(150000):strip_icc()/IMG_2109-522be4678cb44ee6ac1f265c61a81683.jpg
# Completed Image ====> 58.IMG_2109-522be4678cb44ee6ac1f265c61a81683.jpg
# Image URL: https://img.theculturetrip.com/768x432/wp-content/uploads/2015/06/panorama-view-of-munich-city-center-shutterstock_129334115.jpg
# Completed Image ====> 59.panorama-view-of-munich-city-center-shutterstock_129334115.jpg
# Image URL: https://static.toiimg.com/photo/54348102/.jpg
# Completed Image ====> 60..jpg
# Image URL: https://media.cntraveler.com/photos/5c06a5a9e57b552cb75b0eaa/4:3/w_480,c_limit/wintermarkt-161119-304.jpg
# Completed Image ====> 61.wintermarkt-161119-304.jpg
# Image URL: https://lp-cms-production.imgix.net/2019-06/59871922.jpg?fit=crop&q=40&sharp=10&vib=20&auto=format&ixlib=react-8.6.4
# Completed Image ====> 62.59871922.jpg
# Image URL: https://images.wsj.net/im-114081?width=620&size=1.5
# Invalid or missing image format. Skipping...
# Image URL: https://bigseventravel.com/wp-content/uploads/2019/01/Screenshot-2019-01-16-at-21.17.21.png
# Completed Image ====> 63.Screenshot-2019-01-16-at-21.17.21.png
# Image URL: https://media.timeout.com/images/105046319/630/472/image.jpg
# Completed Image ====> 64.image.jpg
# Image URL: https://www.ourescapeclause.com/wp-content/uploads/2018/05/NeuschwanstienCastleOverlook-2-1170x789.jpg
# Completed Image ====> 65.NeuschwanstienCastleOverlook-2-1170x789.jpg
# Image URL: https://image.jimcdn.com/app/cms/image/transf/none/path/sa6549607c78f5c11/image/i22d52086ae4c6247/version/1471781827/munich.jpg
# Completed Image ====> 66.munich.jpg
# Image URL: https://imgcy.trivago.com/c_lfill,d_dummy.jpeg,e_sharpen:60,f_auto,h_450,q_auto,w_450/itemimages/52/16/5216_v2.jpeg
# Completed Image ====> 67.5216_v2.jpeg
# Image URL: https://www.planetware.com/photos-large/D/germany-munich-glockenspiel.jpg
# Completed Image ====> 68.germany-munich-glockenspiel.jpg
# Image URL: https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2019/08/27/yq-munichairport-27082022.jpg?itok=1DeeXVWZ&timestamp=1566899181
# Completed Image ====> 69.yq-munichairport-27082022.jpg
# Image URL: https://www.deutschland.de/sites/default/files/styles/crop_page/public/media/image/munich-germany-bavaria-tourism-travel-holidays-alps.jpg?h=3897af75&itok=6oIWaQ_a
# Completed Image ====> 70.munich-germany-bavaria-tourism-travel-holidays-alps.jpg
# Image URL: https://ihg.scene7.com/is/image/ihg/holiday-inn-munich-5577072340-2x1?wid=2400&hei=1200&qlt=85,0&resMode=sharp2&op_usm=1.75,0.9,2,0&qlt=85,0&resMode=sharp2&op_usm=1.75,0.9,2,0
# Invalid or missing image format. Skipping...
# Image URL: https://www.gpsmycity.com/img/adp/5169.jpg
# Completed Image ====> 71.5169.jpg
# Image URL: https://www.avianca.com/content/dam/avianca_new/destinos/muc/muc_banner_munich_destino.jpg
# IOError on an image...trying next one... Error: The read operation timed out
# Image URL: https://i.ytimg.com/vi/P3CiiqbL2JM/hqdefault.jpg
# Completed Image ====> 72.hqdefault.jpg
# Image URL: https://www.clientearth.org/wp-content/uploads/fairground-blue-sky-munich.jpg
# Completed Image ====> 73.fairground-blue-sky-munich.jpg
# Image URL: https://cdn2.veltra.com/ptr/20170510124315_1099860712_10089_0.jpg?imwidth=480&impolicy=custom
# Completed Image ====> 74.20170510124315_1099860712_10089_0.jpg
# Image URL: https://cdn.expatica.com/production/sites/6/2014/05/15185306/Munich-city-living-1920x1080.jpg
# Completed Image ====> 75.Munich-city-living-1920x1080.jpg
# Image URL: https://media.tacdn.com/media/attractions-splice-spp-674x446/06/73/de/90.jpg
# Completed Image ====> 76.90.jpg
# Image URL: https://www.munich.travel/var/ger_muc/storage/images/_aliases/teaser_medium/2/2/8/5/1495822-1-ger-DE/weihnachtsmarkt-christkindlmarkt-marienplatz-foto-bernd-roemmelt-3000.jpg
# Completed Image ====> 77.weihnachtsmarkt-christkindlmarkt-marienplatz-foto-bernd-roemmelt-3000.jpg
# Image URL: https://turkishairlines.ssl.cdn.sdlmedia.com/image/636062359451279050CF.jpg
# Completed Image ====> 78.636062359451279050CF.jpg
# Image URL: https://www.lastminute.com/holidays/img/germany/munich.jpg
# Completed Image ====> 79.munich.jpg
# Image URL: https://media.timeout.com/images/105149385/630/472/image.jpg
# Completed Image ====> 80.image.jpg
# Image URL: https://www.dw.com/image/51371533_303.jpg
# Completed Image ====> 81.51371533_303.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-1438847-148.jpg
# Completed Image ====> 82.tour_img-1438847-148.jpg
# Image URL: https://i.pinimg.com/236x/d1/ab/ab/d1abab36ecfa49add795ccdd4b2be084--munich-germany-bavaria-germany.jpg
# Completed Image ====> 83.d1abab36ecfa49add795ccdd4b2be084--munich-germany-bavaria-germany.jpg
# Image URL: https://assets.atlasobscura.-Olafur_Eliasson_Umschreibung_Endlose_Treppe_2004_KPMG-Zentrale_Muenchen-1.jpg
# Completed Image ====> 84.728px-Olafur_Eliasson_Umschreibung_Endlose_Treppe_2004_KPMG-Zentrale_Muenchen-1.jpg
# Image URL: https://accesscities.org/wp-content/uploads/2018/12/PPT-Munich_150dpi.jpg
# Completed Image ====> 85.PPT-Munich_150dpi.jpg
# Image URL: https://graftlab.com/wp-content/uploads/2016/04/GRAFT_ApassionataMuenchen_Header1920x950cStefanMuellerNaumann.jpg
# Completed Image ====> 86.GRAFT_ApassionataMuenchen_Header1920x950cStefanMuellerNaumann.jpg
# Image URL: https://travelguide.michelin.com/sites/default/files/styles/poi_slideshow/public/images/travel_guide/voyage_media-NX-40870/munich.jpg
# Completed Image ====> 87.munich.jpg
# Image URL: https://specials-images.forbesimg.com/imageserve/636804866/960x0.jpg?fit=scale
# Completed Image ====> 88.960x0.jpg
# Image URL: https://preview.thenewsmarket.com/Previews/LUFT/StillAssets/535582_v2.JPEG
# Completed Image ====> 89.535582_v2.JPEG
# Image URL: https://media.timeout.com/images/105189161/630/472/image.jpg
# Completed Image ====> 90.image.jpg
# Image URL: https://l4r4vqyd4a42fca2325wc6zk-wpengine.netdna-ssl.com/wp-content/uploads/2019/07/top-ten-day-trips-from-munich-germany-best-side-trips-nuremberg-castle-ww2-sites-2.jpg
# Completed Image ====> 91.top-ten-day-trips-from-munich-germany-best-side-trips-nuremberg-castle-ww2-sites-2.jpg
# Image URL: http://ihg.scene7.com/is/image/ihg/holiday-inn-munich-5557370750-4x3
# Invalid or missing image format. Skipping...
# Image URL: https://happytowander.com/wp-content/uploads/Munich-Christmas-Markets-Marienplatz-0767.jpg
# Completed Image ====> 92.Munich-Christmas-Markets-Marienplatz-0767.jpg
# Image URL: https://prodcmscdn.azureedge.net/careerconnectresources/p/MICRUS/images/locations_munich_media_carousel_welcome_ms_germany-1510573411423.jpg
# Completed Image ====> 93.locations_munich_media_carousel_welcome_ms_germany-1510573411423.jpg
# Image URL: https://www.thelocal.de/userdata/images/article/a1a0540949793b87e08667f0ae3cb3bad1d477a8aa15da382b4e8de4319e92c2.jpg
# Completed Image ====> 94.a1a0540949793b87e08667f0ae3cb3bad1d477a8aa15da382b4e8de4319e92c2.jpg
# Image URL: https://www.dentons.com/-/media/images/website/background-images/offices/munich/munichwebbgimage.jpg?w=1024&h=302&crop=1
# Completed Image ====> 95.munichwebbgimage.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 95 is all we got for this search filter!
#
# Errors: 5
#
#
# Item no.: 2 --> Item name = Berlin
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Aerial_view_of_Berlin_%2832881394137%29.jpg/1200px-Aerial_view_of_Berlin_%2832881394137%29.jpg
# Completed Image ====> 1.1200px-Aerial_view_of_Berlin_%2832881394137%29.jpg
# Image URL: https://www.visitberlin.de/system/files/styles/visitberlin_teaser_block_portrait_visitberlin_mobile_1x/private/image/Berliner_Dom_GettyImages-545636754_Foto_bluejayphoto_DL_PPT_0.jpg?h=5c4fcd23&itok=jNfx3nVl
# Completed Image ====> 2.Berliner_Dom_GettyImages-545636754_Foto_bluejayphoto_DL_PPT_0.jpg
# Image URL: https://www.visitberlin.de/system/files/styles/visitberlin_teaser_single_visitberlin_mobile_1x/private/image/Fernsehturm_iStock_c_bluejayphoto_DL_PPT_0.jpg?h=cbc5e7bf&itok=MfN7PE-c
# Completed Image ====> 3.Fernsehturm_iStock_c_bluejayphoto_DL_PPT_0.jpg
# Image URL: https://www.telegraph.co.uk/content/dam/Travel/Destinations/Europe/Germany/Berlin/berlin-guide-lead-2018.jpg?imwidth=450
# Completed Image ====> 4.berlin-guide-lead-2018.jpg
# Image URL: https://d2bgjx2gb489de.cloudfront.net/gbb-blogs/wp-content/uploads/2016/11/24111943/Berlin-city-view-870x400.jpg
# Completed Image ====> 5.Berlin-city-view-870x400.jpg
# Image URL: https://www.visitberlin.de/system/files/styles/visitberlin_teaser_single_visitberlin_mobile_1x/private/image/_SCH6057_c_Scholvien_PSR_SC_STD_V2_DL_PPT_0.jpg?h=32462309&itok=Xi0CMgn5
# Completed Image ====> 6._SCH6057_c_Scholvien_PSR_SC_STD_V2_DL_PPT_0.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Cityscape_Berlin.jpg/407px-Cityscape_Berlin.jpg
# Completed Image ====> 7.407px-Cityscape_Berlin.jpg
# Image URL: https://www.ef.edu/sitecore/__/~/media/universal/stage/5x2/destinations/de/berlin.jpg?w=375
# Completed Image ====> 8.berlin.jpg
# Image URL: https://www.dw.com/image/43901161_303.jpg
# Completed Image ====> 9.43901161_303.jpg
# Image URL: https://cdn.civitatis.com/alemania/berlin/free-tour-berlin.jpg
# Completed Image ====> 10.free-tour-berlin.jpg
# Image URL: https://media.globalchampionsleague.com/cache/750x429/assets/berlin.jpg
# Completed Image ====> 11.berlin.jpg
# Image URL: https://static01.nyt.com/images/2019/10/27/multimedia/27sp-berlinwall1/merlin_161845386_df20daa9-eabe-41f2-9c02-29056529ef17-articleLarge.jpg?quality=75&auto=webp&disable=upscale
# Completed Image ====> 12.merlin_161845386_df20daa9-eabe-41f2-9c02-29056529ef17-articleLarge.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-629553-146.jpg
# Completed Image ====> 13.tour_img-629553-146.jpg
# Image URL: https://www.berlin.de/binaries/asset/image_assets/5244280/ratio_2_1/1554712090/972x486/
# Invalid or missing image format. Skipping...
# Image URL: https://cdn.contexttravel.com/image/upload/c_fill,q_60,w_2600/v1555943215/production/city/hero_image_18_1555943214.jpg
# Completed Image ====> 14.hero_image_18_1555943214.jpg
# Image URL: https://www.steigenberger.com/cache/images/berlin_fotolia_93887_2206ae4123b62425d56a38c.jpg
# Completed Image ====> 15.berlin_fotolia_93887_2206ae4123b62425d56a38c.jpg
# Image URL: https://www.deutschland.de/sites/default/files/styles/crop_page/public/media/image/T%C3%BCD_Politisches_Zentrum-Berlin_Reichstagsgeb%C3%A4ude.jpg?h=38930298&itok=Qs3QpJM-
# Completed Image ====> 16.T%C3%BCD_Politisches_Zentrum-Berlin_Reichstagsgeb%C3%A4ude.jpg
# Image URL: https://www.eu-startups.com/wp-content/uploads/2018/12/Berlin.png
# Completed Image ====> 17.Berlin.png
# Image URL: https://images.contentstack.io/v3/assets/bltfc5888374a59f773/blta62df7d4a3f7004b/5d4826e7c9f15943d8429534/Berlin_Mitte_iStock-1048311846.jpg?auto=webp&format=pjpg&quality=80&width=640&height=720&fit=crop
# Completed Image ====> 18.Berlin_Mitte_iStock-1048311846.jpg
# Image URL: https://media.timeout.com/images/105303515/image.jpg
# Completed Image ====> 19.image.jpg
# Image URL: https://ca-times.brightspotcdn.com/dims4/default/1b8ea46/2147483647/strip/true/crop/4000x2667+0+0/resize/840x560!/quality/90/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2Fab%2F74%2Fb3ed4128486e8555f9894fd5a41c%2Fgettyimages-1179906677.jpg
# Invalid or missing image format. Skipping...
# Image URL: https://ardsglobal.org/wp-content/uploads/2019/04/berlingermany.jpg
# Completed Image ====> 20.berlingermany.jpg
# Image URL: https://www.berlin-welcomecard.de/sites/default/files/styles/stage_desktop_20x/public/berlin-welcomecard_hero_2880__1.jpg?itok=fgbQwjEO&timestamp=1528123533
# Completed Image ====> 21.berlin-welcomecard_hero_2880__1.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-313352-146.jpg
# Completed Image ====> 22.tour_img-313352-146.jpg
# Image URL: https://cdn2.wanderlust.co.uk/media/1028/dreamstime_m_70248404.jpg?anchor=center&mode=crop&width=1200&height=0&rnd=132047266080000000
# Completed Image ====> 23.dreamstime_m_70248404.jpg
# Image URL: https://static.neweuropetours.eu/wp-content/uploads/2018/08/thio-berlin-05-1600x900-2.jpg
# Completed Image ====> 24.thio-berlin-05-1600x900-2.jpg
# Image URL: https://cdn.britannica.com/s:800x450,c:crop/54/171654-138-2FC473D3/video-Berlin-Germany.jpg
# Completed Image ====> 25.video-Berlin-Germany.jpg
# Image URL: https://static.toiimg.com/photo/53320533/.jpg
# Completed Image ====> 26..jpg
# Image URL: https://handluggageonly.co.uk/wp-content/uploads/2017/01/What-To-See-In-Berlin-10.jpg
# Completed Image ====> 27.What-To-See-In-Berlin-10.jpg
# Image URL: https://www.dw.com/image/45454126_303.jpg
# Completed Image ====> 28.45454126_303.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/0/02/Berlin_Skyline_Fernsehturm_02.jpg
# Completed Image ====> 29.Berlin_Skyline_Fernsehturm_02.jpg
# Image URL: https://www.dw.com/image/18413332_303.jpg
# Completed Image ====> 30.18413332_303.jpg
# Image URL: http://cdn.cnn.com/cnnnext/dam/assets/190603153021-07-berlin-wall-places.jpg
# Completed Image ====> 31.190603153021-07-berlin-wall-places.jpg
# Image URL: https://www.visitberlin.de/system/files/styles/visitberlin_teaser_single_visitberlin_mobile_1x/private/image/ludwigkirchplatz15_c_visitBerlin_Foto_Dagmar_Schwelle_DL_PPT_0.jpg?h=06f6671c&itok=gyECCKpX
# Completed Image ====> 32.ludwigkirchplatz15_c_visitBerlin_Foto_Dagmar_Schwelle_DL_PPT_0.jpg
# Image URL: https://ksassets.timeincuk.net/wp/uploads/sites/46/2017/07/berlin-920x518.jpg
# Completed Image ====> 33.berlin-920x518.jpg
# Image URL: https://cdn2.wanderlust.co.uk/media/1028/dreamstime_m_70248404.jpg?anchor=center&mode=crop&width=600&height=225&rnd=132047266080000000
# Completed Image ====> 34.dreamstime_m_70248404.jpg
# Image URL: https://static3.mansionglobal.com/production/media/article-images/45ef30aec49633414b49e4522017945e/large_take_berlin.jpg
# Completed Image ====> 35.large_take_berlin.jpg
# Image URL: https://spectatorlife.imgix.net/content/uploads/2019/10/iStock-1062386098-e1570500037943.jpg?auto=compress,enhance,format&crop=faces,entropy,edges&fit=crop&w=900&h=600
# Completed Image ====> 36.iStock-1062386098-e1570500037943.jpg
# Image URL: https://www.thelocal.de/userdata/images/article/5c80c06896ebaf4bf708ec0977f136316c9a4d6d6f8a55199c586fd5de937ff6.jpg
# Completed Image ====> 37.5c80c06896ebaf4bf708ec0977f136316c9a4d6d6f8a55199c586fd5de937ff6.jpg
# Image URL: https://www.fodors.com/wp-content/uploads/2018/12/BerlinOutdoor_Hero_11_BerlinOutdoor_Hero_shutterstock_331598504.jpg
# Completed Image ====> 38.BerlinOutdoor_Hero_11_BerlinOutdoor_Hero_shutterstock_331598504.jpg
# Image URL: https://timedotcom.files.wordpress.com/2019/01/martin-luther-king-berlin-wall.jpg
# Completed Image ====> 39.martin-luther-king-berlin-wall.jpg
# Image URL: https://berlin.capribyfraser.com/d/capriberlin/media/Images/Blog_images/berlin-christmas-market.jpg
# Completed Image ====> 40.berlin-christmas-market.jpg
# Image URL: https://media.ticmate.com/resources/ticmate_live/import/TOUR_CMS/1072300/1072339-default.jpg
# Completed Image ====> 41.1072339-default.jpg
# Image URL: https://www.gannett-cdn.com/presto/2019/11/09/USAT/a407f5bc-5ba1-43f0-995a-a8cfe8777b5b-AP_APTOPIX_Germany_Berlin_Wall_Anniversary.JPG?crop=4790,2695,x0,y319&width=3200&height=1801&format=pjpg&auto=webp
# Completed Image ====> 42.a407f5bc-5ba1-43f0-995a-a8cfe8777b5b-AP_APTOPIX_Germany_Berlin_Wall_Anniversary.JPG
# Image URL: https://www.fattiretours.com/uploads/6832/HERO-M-fat-tire-tours-berlin-homepage-2@2x.png
# Completed Image ====> 43.HERO-M-fat-tire-tours-berlin-homepage-2@2x.png
# Image URL: https://www.abercrombiekent.com/-/media/ak/media-for-prod/journeys/tailor-made/tm-germany-berlin-ext-riechstag-mh.jpg?h=500&w=1224&la=en&hash=0746B93AB8381F2E1547B4F24EFE8859
# Completed Image ====> 44.tm-germany-berlin-ext-riechstag-mh.jpg
# Image URL: https://www.pymnts.com/wp-content/uploads/2016/06/tech-center-berlin-germany.jpg
# Completed Image ====> 45.tech-center-berlin-germany.jpg
# Image URL: https://s.yimg.com/uu/api/res/1.2/wiNeMkofy93q0O0qK2Re5Q--~B/aD0xMzM0O3c9MjAwMDtzbT0xO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_politics_602/3434cad54c5cfa3f023bf8b8702b25c4
# Invalid or missing image format. Skipping...
# Image URL: https://handluggageonly.co.uk/wp-content/uploads/2015/02/HandLuggageOnly-8.jpg
# Completed Image ====> 46.HandLuggageOnly-8.jpg
# Image URL: https://www.gannett-cdn.com/presto/2019/11/05/USAT/b84c9522-38e6-4a63-8ca3-d3b7ad660e28-AP_Germany_Wall_Anniversary.JPG?width=2560
# Completed Image ====> 47.b84c9522-38e6-4a63-8ca3-d3b7ad660e28-AP_Germany_Wall_Anniversary.JPG
# Image URL: https://mediad.publicbroadcasting.net/p/shared/npr/styles/x_large/nprshared/201911/777797503.jpg
# Completed Image ====> 48.777797503.jpg
# Image URL: https://ca-times.brightspotcdn.com/dims4/default/f3b49b0/2147483647/strip/true/crop/2046x1151+0+0/resize/840x473!/quality/90/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2Fa1%2F5f%2F66674a2d54c19e1f48ee47fd3e59%2Fla-1560982713-5boc6gzdt1-snap-image
# Invalid or missing image format. Skipping...
# Image URL: https://media.cntraveler.com/photos/5b8594aa26856907ba2a9188/master/w_1200,c_limit/Berlin_GettyImages-702606445.jpg
# Completed Image ====> 49.Berlin_GettyImages-702606445.jpg
# Image URL: https://specials-images.forbesimg.com/imageserve/518023832/960x0.jpg?fit=scale
# Completed Image ====> 50.960x0.jpg
# Image URL: https://az592774.vo.msecnd.net/pgl-release/Images/ArticleImages/19/19133.jpg
# Completed Image ====> 51.19133.jpg
# Image URL: https://www.cleanenergywire.org/sites/default/files/styles/gallery_image/public/img_20191007_082556.jpg?itok=LqaMhbPr
# Completed Image ====> 52.img_20191007_082556.jpg
# Image URL: https://www.be.berlin/fileadmin/user_upload/170407_BePa_Motive_Header_Desktop_1920x1080_Foto_Kopie1.jpg
# Completed Image ====> 53.170407_BePa_Motive_Header_Desktop_1920x1080_Foto_Kopie1.jpg
# Image URL: https://www.thelocal.de/userdata/images/article/2c261c121d6d3a4490e9b37c5afe4724c117ff15589599e977d0c290b0070b95.jpg
# Completed Image ====> 54.2c261c121d6d3a4490e9b37c5afe4724c117ff15589599e977d0c290b0070b95.jpg
# Image URL: https://media.timeout.com/images/105303511/630/472/image.jpg
# Completed Image ====> 55.image.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/5/53/%C3%9Cber_den_D%C3%A4chern_von_Berlin.jpg/365px-%C3%9Cber_den_D%C3%A4chern_von_Berlin.jpg
# Completed Image ====> 56.365px-%C3%9Cber_den_D%C3%A4chern_von_Berlin.jpg
# Image URL: https://static01.nyt.com/images/2019/11/27/world/00ZIERVOGEL-profile/00ZIERVOGEL-profile-articleLarge.jpg?quality=75&auto=webp&disable=upscale
# Completed Image ====> 57.00ZIERVOGEL-profile-articleLarge.jpg
# Image URL: https://www.euractiv.com/wp-content/uploads/sites/2/2019/11/w_55662987-800x450.jpg
# Completed Image ====> 58.w_55662987-800x450.jpg
# Image URL: https://www.berlin.de/binaries/asset/image_assets/3229529/source/1512403085/624x468/
# Invalid or missing image format. Skipping...
# Image URL: https://www.sohohouseberlin.com/system/files/062016/57616e27ebeeb52c9b000001/sqobile/Soho_House_Berlin_16_1460.jpg?1466005489
# Completed Image ====> 59.Soho_House_Berlin_16_1460.jpg
# Image URL: https://i.guim.co.uk/img/media/b4f3c2dae7452e913fa5a931269b8fbdcf617b0d/90_0_3966_2379/master/3966.jpg?width=300&quality=85&auto=format&fit=max&s=353e7989e00db9b752a4df274b1faefc
# Completed Image ====> 60.3966.jpg
# Image URL: https://q-cf.bstatic.com/images/hotel/max1024x768/154/154459180.jpg
# Completed Image ====> 61.154459180.jpg
# Image URL: https://daily.jstor.org/wp-content/uploads/2016/06/Berlin_Wall_Niederkirchnerstra%C3%9Fe_Berlin_1988-1800x1200.jpg
# Completed Image ====> 62.Berlin_Wall_Niederkirchnerstra%C3%9Fe_Berlin_1988-1800x1200.jpg
# Image URL: https://now.tufts.edu/sites/default/files/191108_berlin_wall_david_art_lg.jpg
# Completed Image ====> 63.191108_berlin_wall_david_art_lg.jpg
# Image URL: https://inews.co.uk/images-i.jpimedia.uk/imagefetch/https://inews.co.uk/wp-content/uploads/2019/11/GERMANY-Wall-071659.jpg?width=640
# Completed Image ====> 64.GERMANY-Wall-071659.jpg
# Image URL: https://pix10.agoda.net/hotelImages/8158/0/b773f2c2f7544b6e8d2d83df863ee5ae.jpg?s=1024x768
# Completed Image ====> 65.b773f2c2f7544b6e8d2d83df863ee5ae.jpg
# Image URL: https://oeb.global/oeb-insights/wp-content/uploads/2016/10/Blog-Berlin-move.jpg
# Completed Image ====> 66.Blog-Berlin-move.jpg
# Image URL: https://www.thelocal.de/userdata/images/article/94f6967c621ef98969559bea130b277d6468285c5619386acf7bf8c702c54f19.jpg
# Completed Image ====> 67.94f6967c621ef98969559bea130b277d6468285c5619386acf7bf8c702c54f19.jpg
# Image URL: https://a.cdn-hotels.com/gdcs/production127/d411/b4047ca4-62f8-48ea-8bb2-d5a7cdef265c.jpg
# Completed Image ====> 68.b4047ca4-62f8-48ea-8bb2-d5a7cdef265c.jpg
# Image URL: https://www.caimmo.com/fileadmin/_processed_/3/4/csm_Berlin-Europacity-Cube-Aussen_Washingtonplatz_1c39cc2712.jpg
# Completed Image ====> 69.csm_Berlin-Europacity-Cube-Aussen_Washingtonplatz_1c39cc2712.jpg
# Image URL: https://i1.wp.com/www.nationalreview.com/wp-content/uploads/2019/11/berlin-wall-remnant.jpg?fit=789%2C460&ssl=1
# Completed Image ====> 70.berlin-wall-remnant.jpg
# Image URL: https://r-cf.bstatic.com/images/hotel/max1024x768/140/140941279.jpg
# Completed Image ====> 71.140941279.jpg
# Image URL: https://pix10.agoda.net/hotelImages/277658/-1/fba25e3bb317ea7d31d5624d16b8abba.jpg?s=1024x768
# Completed Image ====> 72.fba25e3bb317ea7d31d5624d16b8abba.jpg
# Image URL: https://static01.nyt.com/images/2019/07/19/travel/19Footsteps-Audre-Lorde-Berlin2/merlin_153974943_a89fd34a-eb72-4380-8b66-f76be1e80b8e-articleLarge.jpg?quality=75&auto=webp&disable=upscale
# Completed Image ====> 73.merlin_153974943_a89fd34a-eb72-4380-8b66-f76be1e80b8e-articleLarge.jpg
# Image URL: https://static.timesofisrael.com/www/uploads/2019/10/000_1LO36B-1024x640.jpg
# Completed Image ====> 74.000_1LO36B-1024x640.jpg
# Image URL: https://www.riotgames.com/darkroom/1440/c2f185cb48161e1bb6c6fea45257bdcb:dfdab8b9364f007f0fd96be0b1cf52be/berlin.jpg
# Completed Image ====> 75.berlin.jpg
# Image URL: https://static.wixstatic.com/media/6e220d_6877c3e4a66e48f6983af1f6d8f05c90~mv2_d_2733_1935_s_2.jpg/v1/fill/w_512,h_465,al_c,q_80,usm_0.66_1.00_0.01/6e220d_6877c3e4a66e48f6983af1f6d8f05c90~mv2_d_2733_1935_s_2.webp
# Completed Image ====> 76.6e220d_6877c3e4a66e48f6983af1f6d8f05c90~mv2_d_2733_1935_s_2.webp
# Image URL: https://www.ef.com/sitecore/__~/media/efcom/2018/ils/destinations/Germany/Berlin/Berlin-Stage-Destop.jpg
# Completed Image ====> 77.Berlin-Stage-Destop.jpg
# Image URL: https://media.tacdn.com/media/attractions-splice-spp-674x446/06/70/7f/a6.jpg
# Completed Image ====> 78.a6.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-2452695-146.jpg
# Completed Image ====> 79.tour_img-2452695-146.jpg
# Image URL: https://media.gadventures.com/media-server/cache/48/cd/48cd39c6929dc9afd9f34afac102109e.jpg
# Completed Image ====> 80.48cd39c6929dc9afd9f34afac102109e.jpg
# Image URL: https://www.dw.com/image/51473531_303.jpeg
# Completed Image ====> 81.51473531_303.jpeg
# Image URL: https://notanomadblog.com/images/travel/berlin/berliner-dom-4.jpg
# Completed Image ====> 82.berliner-dom-4.jpg
# Image URL: https://www.melia.com/dam/jcr:9967e953-a917-4fe8-917a-499d043f83ad/02aMeliaBerlin-General_Facade_Night_(2).jpg
# Completed Image ====> 83.02aMeliaBerlin-General_Facade_Night_(2).jpg
# Image URL: https://www.olxgroup.com/assets/styles/hero/public/2018-02/Berlin.jpg?itok=N4C75yUE
# Completed Image ====> 84.Berlin.jpg
# Image URL: https://media.timeout.com/images/105304047/630/472/image.jpg
# Completed Image ====> 85.image.jpg
# Image URL: https://img.theculturetrip.com/768x432/wp-content/uploads/2019/05/dpd39e.jpg
# Completed Image ====> 86.dpd39e.jpg
# Image URL: https://cdn.britannica.com/39/6839-050-27891400/Brandenburg-Gate-Berlin.jpg
# Completed Image ====> 87.Brandenburg-Gate-Berlin.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-2120000-146.jpg
# Completed Image ====> 88.tour_img-2120000-146.jpg
# Image URL: https://fi.co/system/posts/berlin-cathedral-1882397_1280.jpg
# Completed Image ====> 89.berlin-cathedral-1882397_1280.jpg
# Image URL: https://www.steigenberger.com/cache/images/hyeber30_shr_berlin__ab01770e3e3b62425d56a42b.jpg
# Completed Image ====> 90.hyeber30_shr_berlin__ab01770e3e3b62425d56a42b.jpg
# Image URL: https://media-cdn.tripadvisor.com/media/photo-s/16/44/b7/ac/1-hour-berlin-sightseeing.jpg
# Completed Image ====> 91.1-hour-berlin-sightseeing.jpg
# Image URL: https://www.berlinpass.com/images_lib/366887088_BER19040_Bus_Image_Branderburg_Gate_F(1).jpg
# Completed Image ====> 92.366887088_BER19040_Bus_Image_Branderburg_Gate_F(1).jpg
# Image URL: https://media.licdn.com/dms/image/C5612AQEhoFC_jO474w/article-inline_image-shrink_1500_2232/0?e=1579737600&v=beta&t=hsThXRqo52R0cyvaC9_4uw5pvFgZQhEg7yYWDDyEjb0
# Invalid or missing image format. Skipping...
# Image URL: https://s.marketwatch.com/public/resources/images/MW-HR157_berlin_ZH_20190912053817.jpg
# Completed Image ====> 93.MW-HR157_berlin_ZH_20190912053817.jpg
# Image URL: https://www.thelocal.de/userdata/images/article/2d1a22d17aa688031953f90388185daaae1774fefdd0c2549de31e158ebe8138.jpg
# Completed Image ====> 94.2d1a22d17aa688031953f90388185daaae1774fefdd0c2549de31e158ebe8138.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 94 is all we got for this search filter!
#
# Errors: 6
#
#
# Item no.: 3 --> Item name = Dresden
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/c/c8/Dresden_montage.JPG
# Completed Image ====> 1.Dresden_montage.JPG
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/DD-canaletto-blick.jpg/1000px-DD-canaletto-blick.jpg
# Completed Image ====> 2.1000px-DD-canaletto-blick.jpg
# Image URL: https://www.deutschland.de/sites/default/files/styles/crop_page/public/field_visuals/travel-dresden-semper-opera-opera-ball_a.jpg?itok=WEE3l2Jw
# Completed Image ====> 3.travel-dresden-semper-opera-opera-ball_a.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-2220052-146.jpg
# Completed Image ====> 4.tour_img-2220052-146.jpg
# Image URL: https://m.dw.com/image/15791468_101.jpg
# Completed Image ====> 5.15791468_101.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/a/ae/Dresden_photochrom2.jpg
# Completed Image ====> 6.Dresden_photochrom2.jpg
# Image URL: https://img.theculturetrip.com/768x432/wp-content/uploads/2017/10/blue-hour-2641791_1280.jpg
# Completed Image ====> 7.blue-hour-2641791_1280.jpg
# Image URL: https://www.dresden.de/media/tourismus/sehenswert/493x330_panorama_dresden_altstadt.jpg
# Completed Image ====> 8.493x330_panorama_dresden_altstadt.jpg
# Image URL: https://images.contentstack.io/v3/assets/bltfc5888374a59f773/blt95525986cb4d267f/5d47d8035c5bf77f34eb71f8/Dresden_iStock-887626544.jpg?auto=webp&format=pjpg&quality=80&width=640&height=720&fit=crop
# Completed Image ====> 9.Dresden_iStock-887626544.jpg
# Image URL: https://img.static-kl.com/images/media/33DECCA0-6B8E-488C-85003AB9D55A0E7E/?w=1500&h=500
# Invalid or missing image format. Skipping...
# Image URL: https://www.dresden.de/media/tourismus/1024x600_header_reise_deals_2019_en.jpg
# Completed Image ====> 10.1024x600_header_reise_deals_2019_en.jpg
# Image URL: https://www.tripsavvy.com/thmb/lJNLqCBWtqyLVBQufsEr-UyQ-3U=/1280x854/filters:no_upscale():max_bytes(150000):strip_icc()/183109232-56a3ad7b3df78cf7727e8e8a.jpg
# Completed Image ====> 11.183109232-56a3ad7b3df78cf7727e8e8a.jpg
# Image URL: https://cdn.anadventurousworld.com/wp-content/uploads/2018/08/photos-of-dresden.jpg
# Completed Image ====> 12.photos-of-dresden.jpg
# Image URL: https://www.thetravelmagazine.net/wp-content/uploads/Dresden.jpg
# Completed Image ====> 13.Dresden.jpg
# Image URL: https://grafenwoehr.armymwr.com/application/files/1015/4589/6592/Dresden.jpg
# Completed Image ====> 14.Dresden.jpg
# Image URL: https://images2.minutemediacdn.com/image/upload/c_crop,h_1348,w_2400,x_0,y_0/f_auto,q_auto,w_1100/v1574698202/shape/mentalfloss/609349-gettyimages-871196846.jpg
# Completed Image ====> 15.609349-gettyimages-871196846.jpg
# Image URL: https://media.radissonhotels.net/image/Destination-Pages/Localattraction/16256-118729-f63245058_3XL.jpg?impolicy=HomeHero&gravity=North
# Completed Image ====> 16.16256-118729-f63245058_3XL.jpg
# Image URL: https://tmgs-db.sachsen-tourismus.de/tmgs/api/image?id=5133_Frauenkirche_Dresden.jpeg&width=992&dummy=17
# Invalid or missing image format. Skipping...
# Image URL: https://vcdn.bergfex.at/images/downsized/26/f9e99ffb0e065326_2a29eb32b1a70d07@2x.jpg
# Completed Image ====> 17.f9e99ffb0e065326_2a29eb32b1a70d07@2x.jpg
# Image URL: https://hikebiketravel.com/wp-content/uploads/2014/04/Walking-in-Dresden-Germany-1.jpg
# Completed Image ====> 18.Walking-in-Dresden-Germany-1.jpg
# Image URL: https://image.arrivalguides.com/415x300/13/ae103b068c0615c01000c84a832bdbea.jpg
# Completed Image ====> 19.ae103b068c0615c01000c84a832bdbea.jpg
# Image URL: https://ihg.scene7.com/is/image/ihg/holiday-inn-express-dresden-4227454509-2x1?wid=940&hei=470&qlt=85,0&resMode=sharp2&op_usm=1.75,0.9,2,0
# Invalid or missing image format. Skipping...
# Image URL: https://i.ytimg.com/vi/lWc8iOsirlQ/maxresdefault.jpg
# Completed Image ====> 20.maxresdefault.jpg
# Image URL: https://akm-img-a-in.tosshub.com/indiatoday/images/story/201806/03Fir23-6-STORY.jpeg?4JUbn3BKxIBwoPf55nLxYbU02Z7SLDcp
# Completed Image ====> 21.03Fir23-6-STORY.jpeg
# Image URL: https://www.history.com/.image/ar_16:9%2Cc_fill%2Ccs_srgb%2Cfl_progressive%2Cg_faces:center%2Cq_auto:good%2Cw_768/MTU3ODc5MDg3MjQyNDg3NTE5/dresden.jpg
# Completed Image ====> 22.dresden.jpg
# Image URL: https://img.theculturetrip.com/x/smart/wp-content/uploads/2019/04/eur_ger_dresden.jpg
# Completed Image ====> 23.eur_ger_dresden.jpg
# Image URL: https://media.tacdn.com/media/attractions-splice-spp-674x446/06/6f/6d/1e.jpg
# Completed Image ====> 24.1e.jpg
# Image URL: https://static.euronews.com/articles/stories/04/27/78/78/602x338_cmsv2_0d95575c-841f-5bc0-9063-baf095017fc0-4277878.jpg
# Completed Image ====> 25.602x338_cmsv2_0d95575c-841f-5bc0-9063-baf095017fc0-4277878.jpg
# Image URL: https://cdn.britannica.com/01/129101-050-88E4DB18/Frauenkirche-Dresden-Ger-George-Bahr-bombing-Allied-2005.jpg
# Completed Image ====> 26.Frauenkirche-Dresden-Ger-George-Bahr-bombing-Allied-2005.jpg
# Image URL: https://i.ytimg.com/vi/GXco8d1Wa1E/maxresdefault.jpg
# Completed Image ====> 27.maxresdefault.jpg
# Image URL: https://www.dw.com/image/38172948_303.jpg
# Completed Image ====> 28.38172948_303.jpg
# Image URL: https://ihg.scene7.com/is/image/ihg/hotel-indigo-dresden-5689977427-2x1?fit=fit,1&wid=2400&hei=1200&qlt=85,0&resMode=sharp2&op_usm=1.75,0.9,2,0
# Invalid or missing image format. Skipping...
# Image URL: https://blog.klm.com/assets/uploads/2016/05/shutterstock_336492917.jpg
# Completed Image ====> 29.shutterstock_336492917.jpg
# Image URL: https://media.tacdn.com/media/attractions-splice-spp-674x446/06/6f/0c/90.jpg
# Completed Image ====> 30.90.jpg
# Image URL: https://www.leonardo-hotels.com/octopus/upload/images/pages/dresden-7-.jpg
# Completed Image ====> 31.dresden-7-.jpg
# Image URL: https://www.cosmoconsult.com/fileadmin/user_upload/Deutschland/Header_Visual/cosmo-consult-locations-germany-dresden-istock-6566923.jpg
# Completed Image ====> 32.cosmo-consult-locations-germany-dresden-istock-6566923.jpg
# Image URL: https://kurtvonnegut-tour.com/____impro/1/onewebmedia/Page%201_edited2.jpg?etag=%226cbb3-5a3d6a47%22&sourceContentType=image%2Fjpeg&ignoreAspectRatio&resize=970%2B645&quality=85
# Completed Image ====> 33.Page%201_edited2.jpg
# Image URL: https://www.wanderlustchloe.com/wp-content/uploads/2018/06/Dresden-12.jpg
# Completed Image ====> 34.Dresden-12.jpg
# Image URL: https://dresden-weihnachten.info/wp-content/uploads/2018/11/1200x630-Dresden-Advent-Neumarkt-JoergSchoener.jpg
# Completed Image ====> 35.1200x630-Dresden-Advent-Neumarkt-JoergSchoener.jpg
# Image URL: https://image.jimcdn.com/app/cms/image/transf/none/path/sa6549607c78f5c11/image/i9df9a155d8bb0650/version/1538736324/dresden-xmas.jpg
# Completed Image ====> 36.dresden-xmas.jpg
# Image URL: https://www.danflyingsolo.com/wp-content/uploads/2018/12/DresdenChristmasMarkets_Saxony_DanielJamesClarke_21.jpg
# Completed Image ====> 37.DresdenChristmasMarkets_Saxony_DanielJamesClarke_21.jpg
# Image URL: https://i.guim.co.uk/img/media/bce65d473518bdea5f4efab0ed72f6db2ac700bf/0_54_5000_3000/master/5000.jpg?width=300&quality=85&auto=format&fit=max&s=9381a5582c601ac99d6b6e2f980b1f2b
# Completed Image ====> 38.5000.jpg
# Image URL: https://cdn.getyourguide.com/img/tour_img-1550403-146.jpg
# Completed Image ====> 39.tour_img-1550403-146.jpg
# Image URL: https://ihg.scene7.com/is/image/ihg/hotel-indigo-dresden-5689979099-2x1?fit=fit,1&wid=2400&hei=1200&qlt=85,0&resMode=sharp2&op_usm=1.75,0.9,2,0
# Invalid or missing image format. Skipping...
# Image URL: https://static.timesofisrael.com/www/uploads/2017/08/AP_070731053644-e1502621792742.jpg
# Completed Image ====> 40.AP_070731053644-e1502621792742.jpg
# Image URL: https://www.youcouldtravel.com/sites/default/files/styles/yct_crp_sq_min_scale_960/public/featured-images/our-romantic-dresden-itinerary.jpg
# Completed Image ====> 41.our-romantic-dresden-itinerary.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/1/17/Bundesarchiv_Bild_146-1994-041-07%2C_Dresden%2C_zerst%C3%B6rtes_Stadtzentrum.jpg
# Completed Image ====> 42.Bundesarchiv_Bild_146-1994-041-07%2C_Dresden%2C_zerst%C3%B6rtes_Stadtzentrum.jpg
# Image URL: https://www.saechsische-schweiz.de/fileadmin/_processed_/csm_header_dresden_silhouette_Sabine_Kipus_fotolia_42355789_bfa_3aae6a4883.jpg
# Completed Image ====> 43.csm_header_dresden_silhouette_Sabine_Kipus_fotolia_42355789_bfa_3aae6a4883.jpg
# Image URL: https://www.dw.com/image/50907157_401.jpg
# Completed Image ====> 44.50907157_401.jpg
# Image URL: https://cdn-image.travelandleisure.com/sites/default/files/styles/1600x1000/public/1574712414/burglary-green-vault-dresden-JEWELTHEFT1119.jpg?itok=SDcGySTs
# Completed Image ====> 45.burglary-green-vault-dresden-JEWELTHEFT1119.jpg
# Image URL: https://www.lufthansa.com/content/dam/lh/images/offers/destination/drs-panorama.jpg
# Completed Image ====> 46.drs-panorama.jpg
# Image URL: http://static1.squarespace.com/static/50ff0c7ae4b071a5b424f9b7/59af0337cd39c38dabcc2611/59b6fdb42d83c3a07ca3b140/1507293767596/download+%2817%29.jpg?format=1500w
# Completed Image ====> 47.download+%2817%29.jpg
# Image URL: https://www.thevintagenews.com/wp-content/uploads/2016/04/tyupo.jpg
# Completed Image ====> 48.tyupo.jpg
# Image URL: https://cdn.getyourguide.com/img/location_img-20-4120166250-148.jpg
# Completed Image ====> 49.location_img-20-4120166250-148.jpg
# Image URL: https://www.insidehook.com/wp-content/uploads/2019/11/GettyImages-1177947327.jpg?fit=1024%2C723
# Completed Image ====> 50.GettyImages-1177947327.jpg
# Image URL: https://media-cdn.tripadvisor.com/media/photo-s/19/7e/0e/27/elbufer-dresden-20.jpg
# Completed Image ====> 51.elbufer-dresden-20.jpg
# Image URL: https://m.raileurope-world.com/local/cache-vignettes/L320xH214/istock_81616515_large-67f85.jpg?1571944197
# Completed Image ====> 52.istock_81616515_large-67f85.jpg
# Image URL: https://i.ytimg.com/vi/r0LmIhq8sqQ/maxresdefault.jpg
# Completed Image ====> 53.maxresdefault.jpg
# Image URL: https://cdn.britannica.com/s:500x350/62/8662-004-8F1D6128/Zwinger-Dresden-Germany.jpg
# Completed Image ====> 54.Zwinger-Dresden-Germany.jpg
# Image URL: https://www.goodnewsnetwork.org/wp-content/uploads/2015/11/Frauenkirche-dresden-church-before-after-CC-David-Mu%CC%88ller-750px.jpg
# Completed Image ====> 55.Frauenkirche-dresden-church-before-after-CC-David-Mu%CC%88ller-750px.jpg
# Image URL: https://www.bu.edu/abroad/files/2016/05/banner-dresden4.jpg
# Completed Image ====> 56.banner-dresden4.jpg
# Image URL: https://www.optionstheedge.com/sites/default/files/field/featured-image/2019/zwinger_palacec.jpg
# Completed Image ====> 57.zwinger_palacec.jpg
# Image URL: https://s.yimg.com/ny/api/res/1.2/VNYfSWnfKioRaLjxGbv45Q--~A/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/https://media.zenfs.com/en-ca/cp.org/74c7c7dc8120bd048b97d7128aa40260
# Invalid or missing image format. Skipping...
# Image URL: https://s24748.pcdn.co/wp-content/uploads/2019/08/Day-trips-Dresden-featured-588-.jpg
# Completed Image ====> 58.Day-trips-Dresden-featured-588-.jpg
# Image URL: https://en.aegeanair.com/-/media/images/heroimages/dresden_final_cover.jpg?h=800&w=1920&la=en&hash=066CCA6A9FB508A408D6B22310E7C3FD
# Completed Image ====> 59.dresden_final_cover.jpg
# Image URL: https://www.thetravelmagazine.net/wp-content/uploads/Dresden-Frauenkirche.jpg
# Completed Image ====> 60.Dresden-Frauenkirche.jpg
# Image URL: https://www.cityskyliner.com/en/wp-content/uploads/2018/12/cityskyliner_dresden03.jpg
# Completed Image ====> 61.cityskyliner_dresden03.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/a/ad/Striezelmarkt_2009_00950.jpg
# Completed Image ====> 62.Striezelmarkt_2009_00950.jpg
# Image URL: https://c8.alamy.com/comp/MNEH01/dresden-MNEH01.jpg
# Completed Image ====> 63.dresden-MNEH01.jpg
# Image URL: https://www.math.tu-dresden.de/num/icoep2019/Dresden_elbpanorama_klein.jpg
# URLError on an image...trying next one... Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1076)>
# Image URL: https://www.armytimes.com/resizer/sSHP3VY5NbLF-mNOxRcGJC1xLBI=/1200x0/filters:quality(100)/arc-anglerfish-arc2-prod-mco.s3.amazonaws.com/public/MDCACDAUTZEGLMTWU6VJ45JK5M.jpg
# Completed Image ====> 64.MDCACDAUTZEGLMTWU6VJ45JK5M.jpg
# Image URL: https://cdn.flixbus.de/d7files/hi_res_images/header/355_dresden.jpg
# Completed Image ====> 65.355_dresden.jpg
# Image URL: https://static.independent.co.uk/s3fs-public/thumbnails/image/2013/04/05/09/dresden.jpg?width=1000&height=614&fit=bounds&format=pjpg&auto=webp&quality=70&crop=16:9,offset-y0.5
# Completed Image ====> 66.dresden.jpg
# Image URL: https://www.planetware.com/photos-large/D/neumarkt.jpg
# Completed Image ====> 67.neumarkt.jpg
# Image URL: https://a.cdn-hotels.com/gdcs/production45/d1501/1f288120-68ce-11e8-9862-0242ac11003c.jpg
# Completed Image ====> 68.1f288120-68ce-11e8-9862-0242ac11003c.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Dresden-nightpanorama-dri.jpg/1000px-Dresden-nightpanorama-dri.jpg
# Completed Image ====> 69.1000px-Dresden-nightpanorama-dri.jpg
# Image URL: https://www.internations.org/seo-assets/static/d648d958e0a4a0309164ee8b9d1559e0/e848c/289.jpg
# Completed Image ====> 70.289.jpg
# Image URL: https://www.cityskyliner.com/en/wp-content/uploads/2018/12/cityskyliner_dresden02.jpg
# Completed Image ====> 71.cityskyliner_dresden02.jpg
# Image URL: https://s3-eu-west-1.amazonaws.com/uploads.services.internations.org/files/2018/11/03120510/moving-to-dresden-2400x1198.jpg
# Completed Image ====> 72.moving-to-dresden-2400x1198.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/0/02/Canaletto_-_Dresden_seen_from_the_Right_Bank_of_the_Elbe%2C_beneath_the_Augusts_Bridge_-_Google_Art_Project.jpg
# Completed Image ====> 73.Canaletto_-_Dresden_seen_from_the_Right_Bank_of_the_Elbe%2C_beneath_the_Augusts_Bridge_-_Google_Art_Project.jpg
# Image URL: https://images.squarespace-cdn.com/content/v1/589c3f5a6a4963015506bf00/1557934250161-U11F21D3BA9TRVXPPCX9/ke17ZwdGBToddI8pDm48kIWvDotXVJzpaB9U4uJgFAZ7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UYkw0COJ0jfubIceOrpgBczNn-D2MuQxmE8W6LTSTa2QbJ_PhUOUYvzq3c52saRgjQ/WhatsApp+Image+2019-05-15+at+5.28.32+PM%281%29.jpeg
# Completed Image ====> 74.WhatsApp+Image+2019-05-15+at+5.28.32+PM%281%29.jpeg
# Image URL: https://secure.i.telegraph.co.uk/multimedia/archive/01910/dresden-church_1910305b.jpg
# Completed Image ====> 75.dresden-church_1910305b.jpg
# Image URL: http://www.thetimes.co.uk/imageserver/image/methode%2Ftimes%2Fprod%2Fweb%2Fbin%2Fe3d536e4-bdd7-11e9-a4f3-ef0e7047cb9e.jpg?crop=2304%2C1296%2C30%2C100&resize=685
# Completed Image ====> 76.methode%2Ftimes%2Fprod%2Fweb%2Fbin%2Fe3d536e4-bdd7-11e9-a4f3-ef0e7047cb9e.jpg
# Image URL: https://www.saechsische-schweiz.de/fileadmin/_processed_/csm__c__Ansebach_-_fotolia.com_Dresden_w_da225ca431.jpg
# Completed Image ====> 77.csm__c__Ansebach_-_fotolia.com_Dresden_w_da225ca431.jpg
# Image URL: https://pix10.agoda.net/hotelImages/171130/0/1d56b6f4f9eb07220d2f4fac2e06252c.jpg?s=1024x768
# Completed Image ====> 78.1d56b6f4f9eb07220d2f4fac2e06252c.jpg
# Image URL: https://img.theculturetrip.com/768x432/wp-content/uploads/2017/10/striezelmarkt_580-2014_dresden_09.jpg
# Completed Image ====> 79.striezelmarkt_580-2014_dresden_09.jpg
# Image URL: https://i.ytimg.com/vi/1ZF3kCjul84/maxresdefault.jpg
# Completed Image ====> 80.maxresdefault.jpg
# Image URL: https://dimg04.c-ctrip.com/images/fd/tg/g3/M05/7E/E7/CggYGVXNhiuAQKirAAdDO8v2Pz0936_C_750_350.jpg?proc=source%2Ftrip
# Completed Image ====> 81.CggYGVXNhiuAQKirAAdDO8v2Pz0936_C_750_350.jpg
# Image URL: https://miro.medium.com/max/12000/1*omc1cZy60c_2IaUWPvuFGw.jpeg
# Completed Image ====> 82.1*omc1cZy60c_2IaUWPvuFGw.jpeg
# Image URL: https://www.dw.com/image/2094030_4.jpg
# Completed Image ====> 83.2094030_4.jpg
# Image URL: https://www.telegraph.co.uk/content/dam/Travel/Destinations/Europe/Germany/Dresden/Dresden-opera.jpg?imwidth=450
# Completed Image ====> 84.Dresden-opera.jpg
# Image URL: https://thumbs.dreamstime.com/z/dresden-germany-aerial-view-frauenkirche-hofkirche-augustus-bridge-97506515.jpg
# Completed Image ====> 85.dresden-germany-aerial-view-frauenkirche-hofkirche-augustus-bridge-97506515.jpg
# Image URL: https://r-cf.bstatic.com/images/hotel/max1024x768/207/207922116.jpg
# Completed Image ====> 86.207922116.jpg
# Image URL: https://ichef.bbci.co.uk/images/ic/720x405/p07w3qsr.jpg
# Completed Image ====> 87.p07w3qsr.jpg
# Image URL: https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/police-cordon-hangs-in-front-of-the-royal-palace-that-news-photo-1574722253.jpg
# Completed Image ====> 88.police-cordon-hangs-in-front-of-the-royal-palace-that-news-photo-1574722253.jpg
# Image URL: https://www.bu.edu/abroad/files/2016/05/banner-dresden2.jpg
# Completed Image ====> 89.banner-dresden2.jpg
# Image URL: https://uploads.volkswagen-newsroom.com/system/production/media/31216/images/b58886621a7978b5f9885e9095423f4f7f58a9e9/DB2019AL02591_x750.jpg?1574082222
# Completed Image ====> 90.DB2019AL02591_x750.jpg
# Image URL: https://www.deutschland.de/sites/default/files/styles/crop_page/public/article_images/pimg_184114_Reise_Dresden_Tourismus_A.jpg?itok=pJxAl0-J
# Completed Image ====> 91.pimg_184114_Reise_Dresden_Tourismus_A.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Dresden_Altstadt_old_town_%2824924366370%29.jpg/267px-Dresden_Altstadt_old_town_%2824924366370%29.jpg
# Completed Image ====> 92.267px-Dresden_Altstadt_old_town_%2824924366370%29.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/6/6d/Dresden%2C_Schloss_Dresden_Dm_vanaf_de_Sophienstrasse_IMG_8188_2018-08-14_18.16.jpg
# Completed Image ====> 93.Dresden%2C_Schloss_Dresden_Dm_vanaf_de_Sophienstrasse_IMG_8188_2018-08-14_18.16.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 93 is all we got for this search filter!
#
# Errors: 7
#
# ({'Munich': ['/home/jupyter/dlff-note/materials/dataset/pkg/Munich/1.neues-rathaus-marienplatz.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/2.rathaus-sonne-hp.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/3.1200px-Stadtbild_M%C3%BCnchen.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/4.tour_img-1378911-146.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/5.24PTG-Germany3-promo-superJumbo-v2.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/6.munich-alamy.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/7.maxresdefault.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/8.frauenkirche-4000.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/9.merlin_160243626_f8f7f6c4-c329-4dff-af05-be978da4ac42-articleLarge.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/10.Hand-Luggage-Only-2-1.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/11.munich-germany-bavaria-tourism-travel-holidays-alps.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/12.image.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/13.default.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/14.thio-mun-ft-4-1600x900.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/15.event-munich-620x370.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/16.Munich_-_Thumbnail.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/17.tour_img-1378998-146.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/18.Munich-Stage-Destop.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/19.Munich-Germany.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/20.christkindlmarkt-marienplat-logo-hp.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/21.GettyImages-962642536-33584e0b843c4c2ba25e7e7922c97745.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/22.Munich-KellyPrinceWright-2-1.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/23.ccimage-shutterstock_566911099.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/24.munichv2.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/25.8c29596c9f6db671bc25a5a5abc5d7cdec93f79ec9a53c81c4516490dcdf1185.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/26.twin-towers-Church-of-Our-Lady-Munich.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/27.HERO-M-fat-tire-tours-munich-homepage@2x.png', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/28.munich-gty-jpo-170915_31x13_992.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/29.munich2.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/30.Munich-centre.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/31.munich-destination.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/32.friedensengel-aussicht-hp.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/33.town-hall-3620496_1280.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/34.munich.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/35.antiquarium.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/36.large.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/37.tour_img-1025172-146.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/38.image.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/39.weekend-in-munich.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/40.munich-skyline-1565192839.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/41.munich-GettyImages-1145233171.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/42.Patrons-Oktoberfest-beer-garden-Munich-Germany.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/43.20180511125344_96471845_10339_0.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/44.jobs.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/45.Innsbruck.jpg', '/home/jupyter/dlff-note/materials/dataset/pkg/Munich/46.81.jpg', ' ...

# %% [markdown]
# ## Clean data

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
# from url
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %%
os.listdir(out_dir)
# Out:
# ['Dresden', 'Munich', 'Berlin']

# %%
# from package
for c in os.listdir(out_dir):
    print(c)
    verify_images(os.path.join(out_dir,c), delete=True, max_size=300)

# %% [markdown]
# ## View data

# %%
path
# Out:
# PosixPath('../../materials/dataset/url')

# %%
np.random.seed(0)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
np.random.seed(0)
data_pkg = ImageDataBunch.from_folder(out_dir, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(0)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['Berlin', 'Dresden', 'Munich']

# %% [markdown]
# #### Data from url

# %%
data.show_batch(rows=6, figsize=(10,16))

# %% [markdown]
# #### Data from package

# %%
data_pkg.show_batch(rows=6, figsize=(10,16))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Berlin', 'Dresden', 'Munich'], 3, 432, 108)
# (['Berlin', 'Munich'], 2, 144, 35)

# %%
data_pkg.classes, data_pkg.c, len(data_pkg.train_ds), len(data_pkg.valid_ds)
# Out:
# (['Berlin', 'Dresden', 'Munich'], 3, 216, 53)

# %% [markdown]
# ## Train model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn_pkg = cnn_learner(data_pkg, models.resnet34, metrics = error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.889463</td>
#       <td>1.545052</td>
#       <td>0.601852</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.710258</td>
#       <td>1.450653</td>
#       <td>0.546296</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.508953</td>
#       <td>1.517662</td>
#       <td>0.574074</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.380722</td>
#       <td>1.577128</td>
#       <td>0.555556</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_pkg.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.844168</td>
#       <td>2.178552</td>
#       <td>0.641509</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.550801</td>
#       <td>1.112590</td>
#       <td>0.396226</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.322066</td>
#       <td>1.094853</td>
#       <td>0.320755</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.146411</td>
#       <td>1.149493</td>
#       <td>0.358491</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn_pkg.save('stage-1-pkg')

# %%
learn.unfreeze()

# %%
learn_pkg.unfreeze()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.186747</td>
#       <td>1.712747</td>
#       <td>0.574074</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.076185</td>
#       <td>1.702870</td>
#       <td>0.601852</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_pkg.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.598600</td>
#       <td>1.114446</td>
#       <td>0.396226</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.563353</td>
#       <td>1.100469</td>
#       <td>0.377358</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot()

# %%
learn_pkg.recorder.plot()

# %%
### NOTHING>>>>>>>>>>>>>>>>

# %% [markdown]
# #### change learning rate

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_pkg.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# %%script false
# learn.recorder.plot??
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-100-7f2d1b8be8cf> in <module>
# ----> 1 get_ipython().run_cell_magic('script', 'false', 'learn.recorder.plot??\n')
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2350             with self.builtin_trap:
#    2351                 args = (magic_arg_s, cell)
# -> 2352                 result = fn(*args, **kwargs)
#    2353             return result
#    2354
#
# </opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'learn.recorder.plot??\n'' returned non-zero exit status 1.

# %%
learn.recorder.plot()

# %%
#when {city} Germany
learn_pkg.recorder.plot()

# %%
learn.save('stage-2')

# %%
learn_pkg.save('stage-2-pkg')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
learn_pkg.load('stage-2-pkg')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (216 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Dresden,Dresden,Dresden,Dresden,Dresden
# Path: /home/jupyter/dlff-note/materials/dataset/pkg;
#
# Valid: LabelList (53 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Berlin,Berlin,Dresden,Berlin,Berlin
# Path: /home/jupyter/dlff-note/materials/dataset/pkg;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=3, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function error_rate at 0x7f04eecf84d0>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/jupyter/dlff-note/materials/dataset/pkg'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU(inplace=True)
#   (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU(inplace=True)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU(inplace=True)
#   (17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (20): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): ReLU(inplace=True)
#   (22): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (27): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): ReLU(inplace=True)
#   (29): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (30): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (32): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (33): ReLU(inplace=True)
#   (34): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (35): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (37): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace=True)
#   (39): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), Sequential(
#   (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU(inplace=True)
#   (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace=True)
#   (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace=True)
#   (25): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (26): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (27): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace=True)
#   (30): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (33): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): ReLU(inplace=True)
#   (35): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (36): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (39): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU(inplace=True)
#   (42): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (43): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (45): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): ReLU(inplace=True)
#   (47): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (48): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): Flatten()
#   (3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Dropout(p=0.25, inplace=False)
#   (5): Linear(in_features=1024, out_features=512, bias=True)
#   (6): ReLU(inplace=True)
#   (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=512, out_features=3, bias=True)
# )], add_time=True, silent=False)

# %%
interp_url = ClassificationInterpretation.from_learner(learn)

# %%
interp_pkg = ClassificationInterpretation.from_learner(learn_pkg)

# %%
interp_url.plot_confusion_matrix()

# %%
interp_pkg.plot_confusion_matrix()

# %% [markdown]
# ### Data from package is better than url

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .split_none()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.
# If you do run this on Jupyter Lab, you need to restart your runtime and
# runtime state including all local variables will be lost.
ImageCleaner(ds, idxs, path)

# %% [markdown]
# If the code above does not show any GUI(contains images and buttons) rendered by widgets but only text output, that may caused by the configuration problem of ipywidgets. Try the solution in this [link](https://github.com/fastai/fastai/issues/1539#issuecomment-505999861) to solve it.

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, losing all the results from cleaning the data from toplosses.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)

# %%
ImageCleaner(ds, idxs, path, duplicates=True)

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img

# %% [markdown]
# We create our `Learner` in production enviromnent like this, just make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(0)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
