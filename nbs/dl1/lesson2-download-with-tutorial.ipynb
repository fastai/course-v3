# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from fastai.widgets import FileDeleter

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'black'
file = 'urls_black.csv'

# %%
folder = 'teddys'
file = 'urls_teddy.csv'

# %%
folder = 'grizzly'
file = 'urls_grizzly.csv'

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
download_images(path/file, dest, max_pics=200, max_workers=0)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:13<00:00]
#     </div>
# Error https://bloximages.chicago2.vip.townnews.com/montanauntamed.com/content/tncms/assets/v3/editorial/8/2c/82cc48dc-22e9-5b09-8280-7e5f74526021/5b9962af29a53.image.jpg?resize=1200%2C800 'content-length'
# Error https://2zk8ci15bz0240i2m999gkf1-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/Grizzly-bears-are-a-popular-attraction-for-visitors.-Jackson-Hole-EcoTour-Adventures-700x466.jpg 'content-length'
# Error https://bloximages.chicago2.vip.townnews.com/trib.com/content/tncms/assets/v3/editorial/3/5b/35b8ae06-641a-5c49-8739-bf6ea18eb77c/5aff133dd54a6.image.jpg?resize=1200%2C789 'content-length'
# Error http://critterbabies.com/wp-content/uploads/2014/01/2355204850_8ccbcdb9b2.jpg 'content-length'
# Error https://bloximages.newyork1.vip.townnews.com/swnewsmedia.com/content/tncms/assets/v3/editorial/4/43/4430a137-bece-5cea-a2f1-d246a616a5dc/5b9ba8a19d3b8.image.jpg?resize=1200%2C800 'content-length'
# Error https://media.nature.com/w800/magazine-assets/d41586-018-06840-0/d41586-018-06840-0_16150000.jpg 'content-length'
# Error https://media.npr.org/assets/img/2018/07/26/gettyimages-817230638_sq-cf1959aff30c5ddf3cb1ca3cab1162c1856aa176-s800-c85.jpg 'content-length'
# Error https://bloximages.chicago2.vip.townnews.com/missoulian.com/content/tncms/assets/v3/editorial/c/b9/cb9e65e6-c913-5a67-93c1-5747796b386a/5aac5e0e3112d.image.jpg?resize=1200%2C863 'content-length'
# Error https://bloximages.chicago2.vip.townnews.com/rexburgstandardjournal.com/content/tncms/assets/v3/editorial/e/b2/eb2adf98-834c-5379-912a-ea49f2d204f0/5b5a3f729af08.image.jpg?resize=1200%2C797 'content-length'
# Error http://mediad.publicbroadcasting.net/p/kufm/files/styles/x_large/public/201606/grizzly_PD.jpg 'content-length'
# Error https://elknetwork.com/wp-content/uploads/2017/09/mtfwpgrizz-1125x656.jpg 'content-length'

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['teddys','grizzly','black']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# teddys
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='98' class='' max='98', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [98/98 00:02<00:00]
#     </div>
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/teddys/00000067.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/teddys/00000003.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/teddys/00000099.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/teddys/00000074.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/teddys/00000085.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/teddys/00000030.jpg'
# grizzly
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='189' class='' max='189', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [189/189 00:03<00:00]
#     </div>
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000170.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000007.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000167.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000013.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000176.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000016.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000149.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000177.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000029.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000014.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000072.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000065.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000060.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000128.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000114.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000132.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000131.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000097.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000081.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000122.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000144.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000157.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000036.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000168.jpg'
# cannot identify image file '/Users/zachcaceres/fastai-course-v3/nbs/dl1/data/bears/grizzly/00000155.jpg'
# black
# /Users/zachcaceres/anaconda3/envs/fastai/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:754: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33 bytes but only got 32. Skipping tag 42036
#   " Skipping tag %s" % (size, len(data), tag))
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='166' class='' max='166', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [166/166 00:04<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 329, 93)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 02:21
# epoch  train_loss  valid_loss  error_rate
# 1      0.133653    0.169924    0.043011    (02:21)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d81c6bd29d71> in <module>
# ----> 1 learn.lr_find()
#
# ~/fastai/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, **kwargs)
#      28     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      29     a = int(np.ceil(num_it/len(learn.data.train_dl)))
# ---> 30     learn.fit(a, start_lr, callbacks=[cb], **kwargs)
#      31
#      32 def to_fp16(learn:Learner, loss_scale:float=512., flat_master:bool=False)->Learner:
#
# ~/fastai/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     160         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     161         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 162             callbacks=self.callbacks+callbacks)
#     163
#     164     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/fastai/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      85                 if cb_handler.on_batch_end(loss): break
#      86
#
# ~/fastai/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if opt is not None:
#      25         loss = cb_handler.on_backward_begin(loss)
# ---> 26         loss.backward()
#      27         cb_handler.on_backward_end()
#      28         opt.step()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      94                 products. Defaults to ``False``.
#      95         """
# ---> 96         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      97
#      98     def register_hook(self, hook):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# /Users/zachcaceres/anaconda3/envs/fastai/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:754: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33 bytes but only got 32. Skipping tag 42036
#   " Skipping tag %s" % (size, len(data), tag))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-7a5647b6db5d> in <module>
# ----> 1 learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
#
# ~/fastai/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/fastai/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     160         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     161         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 162             callbacks=self.callbacks+callbacks)
#     163
#     164     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/fastai/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      85                 if cb_handler.on_batch_end(loss): break
#      86
#
# ~/fastai/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      16     if not is_listy(xb): xb = [xb]
#      17     if not is_listy(yb): yb = [yb]
# ---> 18     out = model(*xb)
#      19     out = cb_handler.on_loss_begin(out)
#      20
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#      43         out = self.relu(out)
#      44
# ---> 45         out = self.conv2(out)
#      46         out = self.bn2(out)
#      47
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     311     def forward(self, input):
#     312         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 313                         self.padding, self.dilation, self.groups)
#     314
#     315
#
# KeyboardInterrupt:

# %%
learn.save('stage-2')

# %%
learn.load('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(2)

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `file_picker` widget from `widgets` in `fastai` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
def top_losses_paths(interpreter, image_folder, num_of_imgs=None):
    if not num_of_imgs: num_of_imgs = len(image_folder)
    return image_folder[interpreter.top_losses(num_of_imgs)[1]]

# Gets path for every image in validation set
image_folder = data.valid_ds.x
# Sorts file paths according to top_losses from highest to lowest and keeps first `num_of_imgs`
top_loss_paths = top_losses_paths(interp, image_folder)

# %% [markdown]
# Now we can pass in these paths to our widget.

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x…
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.
