# %% [markdown]
# # Welcome to Jupyter Notebooks!

# %% [markdown]
# If you want to learn how to use this tool you've come to the right place. This article will teach you all you need to know to use Jupyter Notebooks effectively.

# %% [markdown]
# You might be reading this tutorial in a web page (maybe Github or the course's webpage). We strongly suggest to read this tutorial in a (yes, you guessed it) Jupyter Notebook. This way you will be able to actually *try* the different commands we will introduce here.

# %% [markdown]
# # Section 1: Need to Know

# %% [markdown]
# # Introduction

# %% [markdown]
# Let's build up from the basics, what is a Jupyter Notebook? Well, you are reading one. It is a document made of cells. You can write like I am writing now (markdown cells) or your can perform calculations in Python (code cells) and run them like this:

# %%
1+1
# Out:
# 2

# %% [markdown]
# Cool huh? This combination of prose and code makes Jupyter Notebook ideal for experimentation: we can see the rationale for each experiment, the code and the results in one comprehensive document. In fastai, each class is documented in a notebook and you can later use that notebook to experiment yourself.
#
# Other renowned institutions in academy and industry use Jupyter Notebook: Google, Microsoft, IBM, Bloomberg, Berkeley and NASA among others. Even Nobel-winning economists [use Jupyter Notebooks](https://paulromer.net/jupyter-mathematica-and-the-future-of-the-research-paper/)  for their experiments and some suggest that Jupyter Notebooks will be the [new format for research papers](https://www.theatlantic.com/science/archive/2018/04/the-scientific-paper-is-obsolete/556676/).

# %% [markdown]
# # Writing

# %% [markdown]
# A type of cell in which you can write like this is called _Markdown_. [_Markdown_](https://en.wikipedia.org/wiki/Markdown) is a very popular markup langauge. To specify that a cell is _Markdown_ you need to click in the drop-down menu in the toolbar and select _Markdown_.

# %% [markdown]
# Click on the the '+' button on the left and select _Markdown_ from the toolbar.

# %% [markdown]
# ![add](imgs/notebook_tutorial/add.png)

# %% [markdown]
# Now you can type your first _Markdown_ cell. We are going to make it a heading. Headings must start with hashtags to specify that they are headings. Write '### My First Notebook' and press run.

# %% [markdown]
# You should see something like this:

# %% [markdown]
# ### My First Notebook

# %% [markdown]
# Now try making your first _Code_ cell: follow the same steps as before but don't change the cell type (when you add a cell its default type is _Code_). Type something like 3/2. You should see '1.5' as output.

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# # Modes

# %% [markdown]
# If you made a mistake in your *Markdown* cell and you have already ran it, you will notice that you cannot edit just by clicking on it. This is because you are in **Command Mode**. Jupyter Notebooks have two distinct modes:
#
# 1. **Edit Mode**: Allows you to edit a cell's content.
#
# 2. **Command Mode**: Allows you to edit the notebook as a whole and use keyboard shortcuts but not edit a cell's content.
#
# You can toggle between these two by either pressing <kbd>ESC</kbd> and <kbd>Enter</kbd> or clicking outside a cell or inside it (you need to double click if its a Markdown cell). You can always know which mode your on since the current cell has a green border if in **Edit Mode** and a blue border in **Command Mode**. Try it!

# %% [markdown]
# ## Other Important Considerations

# %% [markdown]
# 1. Your notebook is autosaved every 120 seconds. If you want to manually save it you can just press the save button on the upper left corner or press <kbd>s</kbd> in **Command Mode**.

# %% [markdown]
# ![Save](imgs/notebook_tutorial/save.png)

# %% [markdown]
# 2. To know if your kernel is computing or not you can check the dot in your upper right corner. If the dot is full, it means that the kernel is working. If not, it is idle. You can place the mouse on it and see the state of the kernel be displayed.

# %% [markdown]
# ![Busy](imgs/notebook_tutorial/busy.png)

# %% [markdown]
# 3. There are a couple of shortcuts you must know about which we use **all** the time (always in **Command Mode**). These are:
#
# <kbd>Shift</kbd>+<kbd>Enter</kbd>: Runs the code or markdown on a cell
#
# <kbd>Up Arrow</kbd>+<kbd>Down Arrow</kbd>: Toggle across cells
#
# <kbd>b</kbd>: Create new cell
#
# <kbd>0</kbd>+<kbd>0</kbd>: Reset Kernel
#
# You can find more shortcuts in the Shortcuts section below.

# %% [markdown]
# 4. You may need to use a terminal in a Jupyter Notebook environment (for example to git pull on a repository). That is very easy to do, just press 'New' in your Home directory and 'Terminal'. Don't know how to use the Terminal? We made a tutorial for that as well. You can find it here.

# %% [markdown]
# ![Terminal](imgs/notebook_tutorial/terminal.png)

# %% [markdown]
# That's it. This is all you need to know to use Jupyter Notebooks. That said, we have more tips and tricks below ↓

# %% [markdown]
# # Section 2: Going deeper

# %% [markdown]
# ## Markdown formatting

# %% [markdown]
# #### Italics, Bold, Strikethrough, Inline, Blockquotes and Links

# %% [markdown]
# The five most important concepts to format your code appropriately when using markdown are:
#
# 1. *Italics*: Surround your text with '\_' or '\*'
# 2. **Bold**: Surround your text with '\__' or '\**'
# 3. `inline`: Surround your text with '\`'
# 4.  > blockquote: Place '\<' before your text.
# 5.  [Links](http://course-v3.fast.ai/): Surround the text you want to link with '\[\]' and place the link adjacent to the text, surrounded with '()'

# %% [markdown]
# #### Headings

# %% [markdown]
# Notice that including a hashtag before the text in a markdown cell makes the text a heading. The number of hashtags you include will determine the priority of the header ('#' is level one, '##' is level two, '###' is level three and '####' is level four). We will add three new cells with the '+' button on the left to see how every level of heading looks.

# %% [markdown]
# # Level one

# %% [markdown]
# ## Level two

# %% [markdown]
# ### Level three

# %% [markdown]
# #### Level four

# %% [markdown]
# Double click on each so you can see how it is defined.

# %% [markdown]
# #### Lists

# %% [markdown]
# There are three types of lists in markdown.

# %% [markdown]
# Ordered list:
#
# 1. Step 1
#     2. Step 1B
# 3. Step 3

# %% [markdown]
# Unordered list
#
# * learning rate
# * cycle length
# * weight decay

# %% [markdown]
# Task list
#
# - [x] Learn Jupyter Notebooks
#     - [x] Writing
#     - [x] Modes
#     - [x] Other Considerations
# - [] Change the world

# %% [markdown]
# Double click on each to see how they are built!

# %% [markdown]
# ## Code Capabilities

# %% [markdown]
# **Code** cells are different than **Markdown** cells in that they have an output cell. This means that we can _keep_ the results of our code within the notebook and share them. Let's say we want to show a graph that explains the result of an experiment. We can just run the necessary cells and save the notebook. The output will be there when we it again! Try it out by running the next four cells.

# %%
# Import necessary libraries
from fastai import *
from fastai.vision import * 
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
a = 1
b = a + 1
c = b + a + 1
d = c + b + a + 1
a, b, c ,d
# Out:
# (1, 2, 4, 8)

# %%
plt.plot([a,b,c,d])
plt.show()

# %% [markdown]
# We can also print images while experimenting. We can even print images that print images, check it out!

# %%
Image.open('imgs/notebook_tutorial/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-bf55429c603b> in <module>()
# ----> 1 Image.open('imgs/notebook_tutorial/Elephant.JPG')
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2578
#    2579     if filename:
# -> 2580         fp = builtins.open(filename, "rb")
#    2581         exclusive_fp = True
#    2582
#
# FileNotFoundError: [Errno 2] No such file or directory: 'imgs/notebook_tutorial/Elephant.JPG'

# %% [markdown]
# ## Running the app locally

# %% [markdown]
# You may be running Jupyter Notebook from an interactive coding enviornment like Gradient, Sagemaker or Salamander. You can also run a Jupyter Notebook server from your local computer. What's more, if you have installed Anaconda you don't even need to install Jupyter (if not, just `pip install jupyter`).
#
# You just need to run `jupyter notebook` in your terminal. Remember to run it from a folder that contains all the folders/files you will want to access. You will be able to open, view and edit files located within the directory in which you run this command but not files in parent directories.
#
# If a browser tab does not open automatically once you run the command, you should CTRL+CLICK the link starting with 'https://localhost:' and this will open a new tab in your default browser.

# %% [markdown]
# ## Creating a notebook

# %% [markdown]
# Click on 'New' in the upper left corner and 'Python 3' in the drop-down list (we are going to use a [Python kernel](https://github.com/ipython/ipython) for all our experiments).
#
# ![new_notebook](imgs/notebook_tutorial/new_notebook.png)
#
# Note: You will sometimes hear people talking about the Notebook 'kernel'. The 'kernel' is just the Python engine that performs the computations for you.

# %% [markdown]
# ## Shortcuts and tricks

# %% [markdown]
# ### Command Mode Shortcuts

# %% [markdown]
# There are a couple of useful keyboard shortcuts in `Command Mode` that you can leverage to make Jupyter Notebook faster to use. Remember that to switch back and forth between `Command Mode` and `Edit Mode` with <kbd>Esc</kbd> and <kbd>Enter</kbd>.

# %% [markdown]
# <kbd>m</kbd>: Convert cell to Markdown

# %% [markdown]
# <kbd>y</kbd>: Convert cell to Code

# %% [markdown]
# <kbd>D</kbd>+<kbd>D</kbd>: Delete cell

# %% [markdown]
# <kbd>o</kbd>: Toggle between hide or show output

# %% [markdown]
# <kbd>Shift</kbd>+<kbd>Arrow up/Arrow down</kbd>: Selects multiple cells. Once you have selected them you can operate on them like a batch (run, copy, paste etc).

# %% [markdown]
# <kbd>Shift</kbd>+<kbd>M</kbd>: Merge selected cells.

# %% [markdown]
# <kbd>Shift</kbd>+<kbd>Tab</kbd>: [press once] Tells you which parameters to pass on a function
# <kbd>Shift</kbd>+<kbd>Tab</kbd>: [press three times] Gives additional information on the method

# %% [markdown]
# ### Cell Tricks

# %%
from fastai import*
from fastai.vision import *

# %% [markdown]
# There are also some tricks that you can code into a cell.

# %% [markdown]
# `?function-name`: Shows the definition and docstring for that function

# %%
# ?ImageMultiDataset

# %% [markdown]
# `??function-name`: Shows the source code for that function

# %%
??ImageMultiDataset

# %% [markdown]
# `doc(function-name)`: Shows the definition, docstring **and links to the documentation** of the function
# (only works with fastai library imported)

# %%
doc(ImageMultiDataset)

# %% [markdown]
# ### Line Magics

# %% [markdown]
# Line magics are functions that you can run on cells and take as an argument the rest of the line from where they are called. You call them by placing a '%' sign before the command. The most useful ones are:

# %% [markdown]
# `%matplotlib inline`: This command ensures that all matplotlib plots will be plotted in the output cell within the notebook and will be kept in the notebook when saved.

# %% [markdown]
# 1. Your notebook is autosaved every 120 seconds. If you want to manually save it you can just press the save button on the upper left corner or press <kbd>Ctrl</kbd>+<kbd>s</kbd>

# %% [markdown]
# 2. To know if your kernel is working or not you can check the dot in your upper right corner. If the dot is full, it means that the kernel is working. If not, it is idle. You can place the mouse on it and see the state of the kernel be displayed.

# %% [markdown]
# `%reload_ext autoreload`, `%autoreload 2`: Reload all modules before executing a new line. If a module is edited, it is not necessary to rerun the import commands, the modules will be reloaded automatically.

# %% [markdown]
# These three commands are always called together at the beggining of every notebook.

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# `%timeit`: Runs a line a ten thousand times and displays the average time it took to run it.

# %%
# %timeit [i+1 for i in range(1000)]
# Out:
# 35.4 µs ± 1.12 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# `%debug`: Allows to inspect a function which is showing an error.

# %%
# %debug
for i in range(1000):
    a = i+1
    b = 'string'
    c = b+1
